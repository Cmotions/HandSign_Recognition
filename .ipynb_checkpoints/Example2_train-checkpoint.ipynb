# %%
"""
The program applies Transfer Learning to this existing model and re-trains it to classify a new set of images.

This example shows how to take a Inception v3 architecture model trained on ImageNet images,
and train a new top layer that can recognize other classes of images.

You can replace the image_dir argument with any folder containing subfolders of
images. The label for each image is taken from the name of the subfolder it's in.

"""
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
#from datetime import datetime
import hashlib
import os.path
import random
import re
import struct
import sys
import tarfile
import time

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

FLAGS = None

# These are all parameters that are tied to the particular model architecture
# we're using for Inception v3. These include things like tensor names and their
# sizes. If you want to adapt this script to work with another model, you will
# need to update these to reflect the values in the network you're using.
DATA_URL = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'

BOTTLENECK_TENSOR_NAME = 'pool_3/_reshape:0'
BOTTLENECK_TENSOR_SIZE = 2048
MODEL_INPUT_WIDTH = 64 #299
MODEL_INPUT_HEIGHT = 48 #299
MODEL_INPUT_DEPTH = 3
JPEG_DATA_TENSOR_NAME = 'DecodeJpeg/contents:0'
RESIZED_INPUT_TENSOR_NAME = 'ResizeBilinear:0'
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M


def create_image_lists(image_dir, testing_percentage, validation_percentage):
    """
    Brief:
        Builds a list of training images from the file system.
        Analyzes the sub folders in the image directory, splits them into stable
        training, testing, and validation sets, and returns a data structure
        describing the lists of images for each label and their paths.
    Args:
        image_dir: String path to a folder containing subfolders of images.
        testing_percentage: Integer percentage of the images to reserve for tests.
        validation_percentage: Integer percentage of images reserved for validation.
    Returns:
        A dictionary containing an entry for each label subfolder, with images split
        into training, testing, and validation sets within each label.
    """
    if not gfile.Exists(image_dir):
        print("Image directory '" + image_dir + "' not found.")
        return None
    result = {}
    sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
    # The root directory comes first, so skip it.
    is_root_dir = True
    for sub_dir in sub_dirs:
        if is_root_dir:
            is_root_dir = False
            continue
        extensions = ['jpg', 'jpeg', 'JPG', 'JPEG' 'png', 'PNG']
        file_list = []
        dir_name = os.path.basename(sub_dir)
        if dir_name == image_dir:
            continue
        print("\nLooking for images in '" + dir_name + "'")
        for extension in extensions:
            file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
            file_list.extend(gfile.Glob(file_glob))
        if not file_list:
            print('No files found')
            continue
        if len(file_list) < 20:
            print('WARNING: Folder has less than 20 images, which may cause issues.')
        elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
            print('WARNING: Folder {} has more than {} images. Some images will '
                  'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
        label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
        training_images = []
        testing_images = []
        validation_images = []
        for file_name in file_list:
            base_name = os.path.basename(file_name)
            # We want to ignore anything after '_nohash_' in the file name when
            # deciding which set to put an image in, the data set creator has a way of
            # grouping photos that are close variations of each other. For example
            # this is used in the plant disease data set to group multiple pictures of
            # the same leaf.
            hash_name = re.sub(r'_nohash_.*$', '', file_name)
            # This looks a bit magical, but we need to decide whether this file should
            # go into the training, testing, or validation sets, and we want to keep
            # existing files in the same set even if more files are subsequently
            # added.
            # To do that, we need a stable way of deciding based on just the file name
            # itself, so we do a hash of that and then use that to generate a
            # probability value that we use to assign it.
            hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
            percentage_hash = ((int(hash_name_hashed, 16) %
                                (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                             (100.0 / MAX_NUM_IMAGES_PER_CLASS))
            if percentage_hash < validation_percentage:
                #print(str(round(percentage_hash, 2)) + " --> added to validation")
                validation_images.append(base_name)
            elif percentage_hash < (testing_percentage + validation_percentage):
                #print(str(round(percentage_hash, 2)) + " --> added to testing")
                testing_images.append(base_name)
            else:
                #print(str(round(percentage_hash, 2)) + " --> added to training")
                training_images.append(base_name)
        result[label_name] = {
            'dir': dir_name,
            'training': training_images,
            'testing': testing_images,
            'validation': validation_images,
            }
    return result


def get_image_path(image_lists, label_name, index, image_dir, category):
    """"
    Brief:
        Returns a path to an image for a label at the given index.
    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Int offset of the image we want. This will be moduloed by the
        available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string of the subfolders containing the training images.
        category: Name string of set to pull images from - training, testing, or validation.
    Returns:
        File system path string to an image that meets the requested parameters.
    """
    if label_name not in image_lists:
        tf.logging.fatal('Label does not exist %s.', label_name)
    label_lists = image_lists[label_name]
    if category not in label_lists:
        tf.logging.fatal('Category does not exist %s.', category)
    category_list = label_lists[category]
    if not category_list:
        tf.logging.fatal('Label %s has no images in the category %s.', label_name, category)
    mod_index = index % len(category_list)
    base_name = category_list[mod_index]
    sub_dir = label_lists['dir']
    full_path = os.path.join(image_dir, sub_dir, base_name)
    print(full_path)
    return full_path


def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category):
    """"
    Brief:
        Returns a path to a bottleneck file for a label at the given index.
    Args:
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be moduloed by the
                available number of images for the label, so it can be arbitrarily large.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        category: Name string of set to pull images from - training, testing, or validation.
    Returns:
        File system path string to an image that meets the requested parameters.
    """
    return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '.txt'


def create_inception_graph():
    """"
    Brief:
        Creates a graph from saved GraphDef file and returns a Graph object.
    Returns:
        Graph holding the trained Inception network, and various tensors we'll be
        manipulating.
    """
    with tf.Graph().as_default() as graph:
        model_filename = os.path.join(FLAGS.model_dir, 'classify_image_graph_def.pb')
        with gfile.FastGFile(model_filename, 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            bottleneck_tensor, jpeg_data_tensor, resized_input_tensor = (
                tf.import_graph_def(graph_def, name='', return_elements=[
                    BOTTLENECK_TENSOR_NAME, JPEG_DATA_TENSOR_NAME,
                    RESIZED_INPUT_TENSOR_NAME]))
    return graph, bottleneck_tensor, jpeg_data_tensor, resized_input_tensor


def run_bottleneck_on_image(sess, image_data, image_data_tensor, bottleneck_tensor):
    """"
    Brief:
        Runs inference on an image to extract the 'bottleneck' summary layer.
    Args:
        sess: Current active TensorFlow Session.
        image_data: String of raw JPEG data.
        image_data_tensor: Input data layer in the graph.
        bottleneck_tensor: Layer before the final softmax.
    Returns:
        Numpy array of bottleneck values.
    """
    bottleneck_values = sess.run(
        bottleneck_tensor,
        {image_data_tensor: image_data})
    bottleneck_values = np.squeeze(bottleneck_values)
    return bottleneck_values


def maybe_download_and_extract():
    """
    Brief:
        Download and extract model tar file.
        If the pretrained model we're using doesn't already exist, this function
        downloads it from the TensorFlow.org website and unpacks it into a directory.
    """
    dest_directory = FLAGS.model_dir
    if not os.path.exists(dest_directory):
        os.makedirs(dest_directory)
    filename = DATA_URL.split('/')[-1]
    filepath = os.path.join(dest_directory, filename)
    if not os.path.exists(filepath):
        def _progress(count, block_size, total_size):
            sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()

        filepath, _ = urllib.request.urlretrieve(DATA_URL, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')
    tarfile.open(filepath, 'r:gz').extractall(dest_directory)


def ensure_dir_exists(dir_name):
    """
    Brief:
        Makes sure the folder exists on disk.
    Args:
        dir_name: Path string to the folder we want to create.
    """
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)


def write_list_of_floats_to_file(list_of_floats, file_path):
    """
    Brief:
        Writes a given list of floats to a binary file.
    Args:
        list_of_floats: List of floats we want to write to a file.
        file_path: Path to a file where list of floats will be stored.
    """
    s = struct.pack('d' * BOTTLENECK_TENSOR_SIZE, *list_of_floats)
    with open(file_path, 'wb') as f:
        f.write(s)


def read_list_of_floats_from_file(file_path):
    """
    Brief:
        Reads list of floats from a given file.
    Args:
        file_path: Path to a file where list of floats was stored.
    Returns:
        Array of bottleneck values (list of floats).
    """
    with open(file_path, 'rb') as f:
        s = struct.unpack('d' * BOTTLENECK_TENSOR_SIZE, f.read())
        return list(s)


bottleneck_path_2_bottleneck_values = {}


def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor):
    """Create a single bottleneck file."""
    print('Creating bottleneck at ' + bottleneck_path)
    image_path = get_image_path(image_lists, label_name, index,
                              image_dir, category)
    if not gfile.Exists(image_path):
        tf.logging.fatal('File does not exist %s', image_path)
    image_data = gfile.FastGFile(image_path, 'rb').read()
    try:
        bottleneck_values = run_bottleneck_on_image(
            sess, image_data, jpeg_data_tensor, bottleneck_tensor)
    except:
        raise RuntimeError('Error during processing file %s' % image_path)

    bottleneck_string = ','.join(str(x) for x in bottleneck_values)
    with open(bottleneck_path, 'w') as bottleneck_file:
        bottleneck_file.write(bottleneck_string)


def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             bottleneck_tensor):
    """
    Brief:
        Retrieves or calculates bottleneck values for an image.

      If a cached version of the bottleneck data exists on-disk, return that,
      otherwise calculate the data and save it to disk for future use.
    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        label_name: Label string we want to get an image for.
        index: Integer offset of the image we want. This will be modulo-ed by the
        available number of images for the label, so it can be arbitrarily large.
        image_dir: Root folder string  of the subfolders containing the training
        images.
        category: Name string of which  set to pull images from - training, testing,
        or validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: The tensor to feed loaded jpeg data into.
        bottleneck_tensor: The output tensor for the bottleneck values.
    Returns:
        Numpy array of values produced by the bottleneck layer for the image.
    """
    label_lists = image_lists[label_name]
    sub_dir = label_lists['dir']
    sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
    ensure_dir_exists(sub_dir_path)
    bottleneck_path = get_bottleneck_path(image_lists, label_name, index,
                                        bottleneck_dir, category)
    if not os.path.exists(bottleneck_path):
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor)
    with open(bottleneck_path, 'r') as bottleneck_file:
        bottleneck_string = bottleneck_file.read()
    did_hit_error = False
    try:
        bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
    except ValueError:
        print('Invalid float found, recreating bottleneck')
        did_hit_error = True
    if did_hit_error:
        create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor)
        with open(bottleneck_path, 'r') as bottleneck_file:
            bottleneck_string = bottleneck_file.read()
        # Allow exceptions to propagate here, since they shouldn't happen after a
        # fresh creation
        bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
    return bottleneck_values


def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor):
    """
    Brief:
        Ensures all the training, testing, and validation bottlenecks are cached.

        Because we're likely to read the same image multiple times (if there are no
        distortions applied during training) it can speed things up a lot if we
        calculate the bottleneck layer values once for each image during
        preprocessing, and then just read those cached values repeatedly during
        training. Here we go through all the images we've found, calculate those
        values, and save them off.
    Args:
        sess: The current active TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        image_dir: Root folder string of the subfolders containing the training
        images.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        jpeg_data_tensor: Input tensor for jpeg data from file.
        bottleneck_tensor: The penultimate output layer of the graph.
    Returns:
        Nothing.
    """
    how_many_bottlenecks = 0
    ensure_dir_exists(bottleneck_dir)
    for label_name, label_lists in image_lists.items():
        for category in ['training', 'testing', 'validation']:
            category_list = label_lists[category]
            for index, unused_base_name in enumerate(category_list):
                get_or_create_bottleneck(sess, image_lists, label_name, index,
                                 image_dir, category, bottleneck_dir,
                                 jpeg_data_tensor, bottleneck_tensor)

                how_many_bottlenecks += 1
                if how_many_bottlenecks % 100 == 0:
                    print(str(how_many_bottlenecks) + ' bottleneck files created.')


def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  bottleneck_tensor):
    """
    Brief:
        Retrieves bottleneck values for cached images.

        If no distortions are being applied, this function can retrieve the cached
        bottleneck values directly from disk for images. It picks a random set of
        images from the specified category.
    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: If positive, a random sample of this size will be chosen.
        If negative, all bottlenecks will be retrieved.
        category: Name string of which set to pull from - training, testing, or
        validation.
        bottleneck_dir: Folder string holding cached files of bottleneck values.
        image_dir: Root folder string of the subfolders containing the training
        images.
        jpeg_data_tensor: The layer to feed jpeg image data into.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.
    Returns:
        List of bottleneck arrays, their corresponding ground truths, and the
        relevant filenames.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    filenames = []
    if how_many >= 0:
        # Retrieve a random sample of bottlenecks.
        for unused_i in range(how_many):
            label_index = random.randrange(class_count)
            label_name = list(image_lists.keys())[label_index]
            image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
            image_name = get_image_path(image_lists, label_name, image_index,
                                  image_dir, category)
            bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                            image_index, image_dir, category,
                                            bottleneck_dir, jpeg_data_tensor,
                                            bottleneck_tensor)
            ground_truth = np.zeros(class_count, dtype=np.float32)
            ground_truth[label_index] = 1.0
            bottlenecks.append(bottleneck)
            ground_truths.append(ground_truth)
            filenames.append(image_name)
    else:
        # Retrieve all bottlenecks.
        for label_index, label_name in enumerate(image_lists.keys()):
            for image_index, image_name in enumerate(
                image_lists[label_name][category]):
                image_name = get_image_path(image_lists, label_name, image_index,
                                    image_dir, category)
                bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                              image_index, image_dir, category,
                                              bottleneck_dir, jpeg_data_tensor,
                                              bottleneck_tensor)
                ground_truth = np.zeros(class_count, dtype=np.float32)
                ground_truth[label_index] = 1.0
                bottlenecks.append(bottleneck)
                ground_truths.append(ground_truth)
                filenames.append(image_name)
    return bottlenecks, ground_truths, filenames


def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor):
    """
    Brief:
        Retrieves bottleneck values for training images, after distortions.

        If we're training with distortions like crops, scales, or flips, we have to
        recalculate the full model for every image, and so we can't use cached
        bottleneck values. Instead we find random images for the requested category,
        run them through the distortion graph, and then the full graph to get the
        bottleneck results for each.
    Args:
        sess: Current TensorFlow Session.
        image_lists: Dictionary of training images for each label.
        how_many: The integer number of bottleneck values to return.
        category: Name string of which set of images to fetch - training, testing,
        or validation.
        image_dir: Root folder string of the subfolders containing the training
        images.
        input_jpeg_tensor: The input layer we feed the image data to.
        distorted_image: The output node of the distortion graph.
        resized_input_tensor: The input node of the recognition graph.
        bottleneck_tensor: The bottleneck output layer of the CNN graph.
    Returns:
        List of bottleneck arrays and their corresponding ground truths.
    """
    class_count = len(image_lists.keys())
    bottlenecks = []
    ground_truths = []
    for unused_i in range(how_many):
        label_index = random.randrange(class_count)
        label_name = list(image_lists.keys())[label_index]
        image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
        image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
        if not gfile.Exists(image_path):
            tf.logging.fatal('File does not exist %s', image_path)
        jpeg_data = gfile.FastGFile(image_path, 'rb').read()
        # Note that we materialize the distorted_image_data as a numpy array before
        # sending running inference on the image. This involves 2 memory copies and
        # might be optimized in other implementations.
        distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
        bottleneck = run_bottleneck_on_image(sess, distorted_image_data,
                                         resized_input_tensor,
                                         bottleneck_tensor)
        ground_truth = np.zeros(class_count, dtype=np.float32)
        ground_truth[label_index] = 1.0
        bottlenecks.append(bottleneck)
        ground_truths.append(ground_truth)
    return bottlenecks, ground_truths


def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
    """
    Brief:
        Whether any distortions are enabled, from the input flags.
    Args:
        flip_left_right: Boolean whether to randomly mirror images horizontally.
        random_crop: Integer percentage setting the total margin used around the
        crop box.
        random_scale: Integer percentage of how much to vary the scale by.
        random_brightness: Integer range to randomly multiply the pixel values by.
    Returns:
        Boolean value indicating whether any distortions should be applied.
    """
    return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))


def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness):
    """
    Brief:
        Creates the operations to apply the specified distortions.

        During training it can help to improve the results if we run the images
        through simple distortions like crops, scales, and flips. These reflect the
        kind of variations we expect in the real world, and so can help train the
        model to cope with natural data more effectively. Here we take the supplied
        parameters and construct a network of operations to apply them to an image.

      Cropping

      Cropping is done by placing a bounding box at a random position in the full
      image. The cropping parameter controls the size of that box relative to the
      input image. If it's zero, then the box is the same size as the input and no
      cropping is performed. If the value is 50%, then the crop box will be half the
      width and height of the input. In a diagram it looks like this:

        <       width         >
        +---------------------+
        |                     |
        |   width - crop%     |
        |    <      >         |
        |    +------+         |
        |    |      |         |
        |    |      |         |
        |    |      |         |
        |    +------+         |
        |                     |
        |                     |
        +---------------------+

      Scaling

      Scaling is a lot like cropping, except that the bounding box is always
      centered and its size varies randomly within the given range. For example if
      the scale percentage is zero, then the bounding box is the same size as the
      input and no scaling is applied. If it's 50%, then the bounding box will be in
      a random range between half the width and height and full size.
    Args:
        flip_left_right: Boolean whether to randomly mirror images horizontally.
        random_crop: Integer percentage setting the total margin used around the
        crop box.
        random_scale: Integer percentage of how much to vary the scale by.
        random_brightness: Integer range to randomly multiply the pixel values by.
        graph.
    Returns:
        The jpeg input layer and the distorted result tensor.
  """

    jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
    decoded_image = tf.image.decode_jpeg(jpeg_data, channels=MODEL_INPUT_DEPTH)
    decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
    decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
    margin_scale = 1.0 + (random_crop / 100.0)
    resize_scale = 1.0 + (random_scale / 100.0)
    margin_scale_value = tf.constant(margin_scale)
    resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
    scale_value = tf.multiply(margin_scale_value, resize_scale_value)
    precrop_width = tf.multiply(scale_value, MODEL_INPUT_WIDTH)
    precrop_height = tf.multiply(scale_value, MODEL_INPUT_HEIGHT)
    precrop_shape = tf.stack([precrop_height, precrop_width])
    precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
    precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
    precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
    cropped_image = tf.random_crop(precropped_image_3d,
                                 [MODEL_INPUT_HEIGHT, MODEL_INPUT_WIDTH,
                                  MODEL_INPUT_DEPTH])
    if flip_left_right:
        flipped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        flipped_image = cropped_image
    brightness_min = 1.0 - (random_brightness / 100.0)
    brightness_max = 1.0 + (random_brightness / 100.0)
    brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
    brightened_image = tf.multiply(flipped_image, brightness_value)
    distort_result = tf.expand_dims(brightened_image, 0, name='DistortResult')
    return jpeg_data, distort_result


def variable_summaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)


def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor):
    """
    Brief:
        Adds a new softmax and fully-connected layer for training.

        We need to retrain the top layer to identify our new classes, so this function
        adds the right operations to the graph, along with some variables to hold the
        weights, and then sets up all the gradients for the backward pass.

        The set up for the softmax and fully-connected layers is based on:
        https://tensorflow.org/versions/master/tutorials/mnist/beginners/index.html
    Args:
        class_count: Integer of how many categories of things we're trying to
        recognize.
        final_tensor_name: Name string for the new final node that produces results.
        bottleneck_tensor: The output of the main CNN graph.
    Returns:
        The tensors for the training and cross entropy results, and tensors for the
        bottleneck input and ground truth input.
    """
    with tf.name_scope('input'):
        bottleneck_input = tf.placeholder_with_default(
                bottleneck_tensor, shape=[None, BOTTLENECK_TENSOR_SIZE],
                name='BottleneckInputPlaceholder')

        ground_truth_input = tf.placeholder(tf.float32,
                                        [None, class_count],
                                        name='GroundTruthInput')

    # Organizing the following ops as `final_training_ops` so they're easier
    # to see in TensorBoard
    layer_name = 'final_training_ops'
    with tf.name_scope(layer_name):
        with tf.name_scope('weights'):
            initial_value = tf.truncated_normal([BOTTLENECK_TENSOR_SIZE, class_count],
                                          stddev=0.001)

            layer_weights = tf.Variable(initial_value, name='final_weights')

            variable_summaries(layer_weights)
        with tf.name_scope('biases'):
            layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
            variable_summaries(layer_biases)
        with tf.name_scope('Wx_plus_b'):
            logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
            tf.summary.histogram('pre_activations', logits)

    final_tensor = tf.nn.softmax(logits, name=final_tensor_name)
    tf.summary.histogram('activations', final_tensor)

    with tf.name_scope('cross_entropy'):
        cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
                labels=ground_truth_input, logits=logits)
        with tf.name_scope('total'):
            cross_entropy_mean = tf.reduce_mean(cross_entropy)
    tf.summary.scalar('cross_entropy', cross_entropy_mean)

    with tf.name_scope('train'):
        optimizer = tf.train.GradientDescentOptimizer(FLAGS.learning_rate)
        train_step = optimizer.minimize(cross_entropy_mean)

    return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
              final_tensor)


def add_evaluation_step(result_tensor, ground_truth_tensor):
    """
    Brief:
        Inserts the operations we need to evaluate the accuracy of our results.
    Args:
        result_tensor: The new final node that produces results.
        ground_truth_tensor: The node we feed ground truth data
        into.
    Returns:
        Tuple of (evaluation step, prediction).
    """
    with tf.name_scope('accuracy'):
        with tf.name_scope('correct_prediction'):
            prediction = tf.argmax(result_tensor, 1)
            correct_prediction = tf.equal(
                    prediction, tf.argmax(ground_truth_tensor, 1))
        with tf.name_scope('accuracy'):
            evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    tf.summary.scalar('accuracy', evaluation_step)
    return evaluation_step, prediction


def main(_):
    # Setup the directory we'll write summaries to for TensorBoard
    if tf.gfile.Exists(FLAGS.summaries_dir):
        tf.gfile.DeleteRecursively(FLAGS.summaries_dir)
    tf.gfile.MakeDirs(FLAGS.summaries_dir)

    # Set up the pre-trained graph.
    maybe_download_and_extract()
    graph, bottleneck_tensor, jpeg_data_tensor, resized_image_tensor = (
            create_inception_graph())

    # Look at the folder structure, and create lists of all the images.
    image_lists = create_image_lists(FLAGS.image_dir, FLAGS.testing_percentage,
                                   FLAGS.validation_percentage)
    class_count = len(image_lists.keys())
    
    if class_count == 0:
        print('No valid folders of images found at ' + FLAGS.image_dir)
        return -1
    if class_count == 1:
        print('Only one valid folder of images found at ' + FLAGS.image_dir +
              ' - multiple classes are needed for classification.')
        return -1

    # See if the command-line flags mean we're applying any distortions.
    do_distort_images = should_distort_images(
            FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
            FLAGS.random_brightness)

    with tf.Session(graph=graph) as sess:

        if do_distort_images:
            # We will be applying distortions, so setup the operations we'll need.
            (distorted_jpeg_data_tensor,
             distorted_image_tensor) = add_input_distortions(
                     FLAGS.flip_left_right, FLAGS.random_crop,
                     FLAGS.random_scale, FLAGS.random_brightness)
        else:
            # We'll make sure we've calculated the 'bottleneck' image summaries and
            # cached them on disk.
            cache_bottlenecks(sess, image_lists, FLAGS.image_dir,
                        FLAGS.bottleneck_dir, jpeg_data_tensor,
                        bottleneck_tensor)

        # Add the new layer that we'll be training.
        (train_step, cross_entropy, bottleneck_input, ground_truth_input,
         final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                            FLAGS.final_tensor_name,
                                            bottleneck_tensor)

        # Create the operations we need to evaluate the accuracy of our new layer.
        evaluation_step, prediction = add_evaluation_step(
                final_tensor, ground_truth_input)

        # Merge all the summaries and write them out to the summaries_dir
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(FLAGS.summaries_dir + '/train',
                                         sess.graph)

        validation_writer = tf.summary.FileWriter(
                FLAGS.summaries_dir + '/validation')

        # Set up all our weights to their initial default values.
        init = tf.global_variables_initializer()
        sess.run(init)

        # Run the training for as many cycles as requested on the command line.
        for i in range(FLAGS.how_many_training_steps):
            print("i = ", str(i))
            # Get a batch of input bottleneck values, either calculated fresh every
            # time with distortions applied, or from the cache stored on disk.
            if do_distort_images:
                (train_bottlenecks,
                 train_ground_truth) = get_random_distorted_bottlenecks(
                         sess, image_lists, FLAGS.train_batch_size, 'training',
                         FLAGS.image_dir, distorted_jpeg_data_tensor,
                         distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
            else:
                (train_bottlenecks,
                 train_ground_truth, _) = get_random_cached_bottlenecks(
                         sess, image_lists, FLAGS.train_batch_size, 'training',
                         FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
                         bottleneck_tensor)
            # Feed the bottlenecks and ground truth into the graph, and run a training
            # step. Capture training summaries for TensorBoard with the `merged` op.

            train_summary, _ = sess.run(
                    [merged, train_step],
                    feed_dict={bottleneck_input: train_bottlenecks,
                               ground_truth_input: train_ground_truth})
            train_writer.add_summary(train_summary, i)

            # Every so often, print out how well the graph is training.
            is_last_step = (i + 1 == FLAGS.how_many_training_steps)
            if (i % FLAGS.eval_step_interval) == 0 or is_last_step:
                train_accuracy, cross_entropy_value = sess.run(
                        [evaluation_step, cross_entropy],
                        feed_dict={bottleneck_input: train_bottlenecks,
                                   ground_truth_input: train_ground_truth})
                validation_bottlenecks, validation_ground_truth, _ = (
                        get_random_cached_bottlenecks(
                                sess, image_lists, FLAGS.validation_batch_size, 'validation',
                                FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
                                bottleneck_tensor))
                # Run a validation step and capture training summaries for TensorBoard
                # with the `merged` op.
                validation_summary, validation_accuracy = sess.run(
                        [merged, evaluation_step],
                        feed_dict={bottleneck_input: validation_bottlenecks,
                                   ground_truth_input: validation_ground_truth})
                validation_writer.add_summary(validation_summary, i)
                print('Step: %d, Train accuracy: %.4f%%, Cross entropy: %f, Validation accuracy: %.1f%% (N=%d)' % (i,
                        train_accuracy * 100, cross_entropy_value, validation_accuracy * 100, len(validation_bottlenecks)))

        # We've completed all our training, so run a final test evaluation on
        # some new images we haven't used before.
        test_bottlenecks, test_ground_truth, test_filenames = (
                get_random_cached_bottlenecks(sess, image_lists, FLAGS.test_batch_size,
                                      'testing', FLAGS.bottleneck_dir,
                                      FLAGS.image_dir, jpeg_data_tensor,
                                      bottleneck_tensor))
        test_accuracy, predictions = sess.run(
                [evaluation_step, prediction],
                feed_dict={bottleneck_input: test_bottlenecks,
                           ground_truth_input: test_ground_truth})
        print('Final test accuracy = %.1f%% (N=%d)' % (
                test_accuracy * 100, len(test_bottlenecks)))

        if FLAGS.print_misclassified_test_images:
            print('=== MISCLASSIFIED TEST IMAGES ===')
            for i, test_filename in enumerate(test_filenames):
                if predictions[i] != test_ground_truth[i].argmax():
                    print('%70s  %s' % (test_filename,
                              list(image_lists.keys())[predictions[i]]))

        # Write out the trained graph and labels with the weights stored as
        # constants.
        output_graph_def = graph_util.convert_variables_to_constants(
                sess, graph.as_graph_def(), [FLAGS.final_tensor_name])
        
        with gfile.FastGFile(FLAGS.output_graph, 'wb') as f:
            f.write(output_graph_def.SerializeToString())
        
        with gfile.FastGFile(FLAGS.output_labels, 'w') as f:
            f.write('\n'.join(image_lists.keys()) + '\n')

# %%
# print the current datetime
print('start: ', str(time.ctime()), '\n')
start = time.time()

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--image_dir',
        type=str,
        default='C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model',
        help='Path to folders of labeled images.'
        )
    parser.add_argument(
        '--output_graph',
        type=str,
        default='logs/output_graph.pb',
        help='Where to save the trained graph.'
        )
    parser.add_argument(
        '--output_labels',
        type=str,
        default='logs/output_labels.txt',
        help='Where to save the trained graph\'s labels.'
        )
    parser.add_argument(
        '--summaries_dir',
        type=str,
        default='logs/retrain_logs',
        help='Where to save summary logs for TensorBoard.'
        )
    parser.add_argument(
        '--how_many_training_steps',
        type=int,
        default=5000,
        help='How many training steps to run before ending.'
        )
    parser.add_argument(
        '--learning_rate',
        type=float,
        default=0.01,
        help='How large a learning rate to use when training.'
        )
    parser.add_argument(
        '--testing_percentage',
        type=int,
        default=10,
        help='What percentage of images to use as a test set.'
        )
    parser.add_argument(
        '--validation_percentage',
        type=int,
        default=10,
        help='What percentage of images to use as a validation set.'
        )
    parser.add_argument(
        '--eval_step_interval',
        type=int,
        default=100,
        help='How often to evaluate the training results.'
        )
    parser.add_argument(
        '--train_batch_size',
        type=int,
        default=100,
        help='How many images to train on at a time.'
        )
    parser.add_argument(
        '--test_batch_size',
        type=int,
        default=-1,
        help="""\
        How many images to test on. This test set is only used once, to evaluate
        the final accuracy of the model after training completes.
        A value of -1 causes the entire test set to be used, which leads to more
        stable results across runs.\
        """
        )
    parser.add_argument(
        '--validation_batch_size',
        type=int,
        default=100,
        help="""\
        How many images to use in an evaluation batch. This validation set is
        used much more often than the test set, and is an early indicator of how
        accurate the model is during training.
        A value of -1 causes the entire validation set to be used, which leads to
        more stable results across training iterations, but may be slower on large
        training sets.\
        """
        )
    parser.add_argument(
        '--print_misclassified_test_images',
        default=False,
        help="""\
        Whether to print out a list of all misclassified test images.\
        """,
        action='store_true'
        )
    parser.add_argument(
        '--model_dir',
        type=str,
        default='logs/imagenet',
        help="""\
        Path to classify_image_graph_def.pb,
        imagenet_synset_to_human_label_map.txt, and
        imagenet_2012_challenge_label_map_proto.pbtxt.\
        """
        )
    parser.add_argument(
        '--bottleneck_dir',
        type=str,
        default='/tmp/bottleneck',
        help='Path to cache bottleneck layer values as files.'
        )
    parser.add_argument(
        '--final_tensor_name',
        type=str,
        default='final_result',
        help="""\
        The name of the output classification layer in the retrained graph.\
        """
        )
    parser.add_argument(
        '--flip_left_right',
        default=False,
        help="""\
        Whether to randomly flip half of the training images horizontally.\
        """,
        action='store_true'
        )
    parser.add_argument(
        '--random_crop',
        type=int,
        default=0,
        help="""\
        A percentage determining how much of a margin to randomly crop off the
        training images.\
        """
        )
    parser.add_argument(
        '--random_scale',
        type=int,
        default=0,
        help="""\
        A percentage determining how much to randomly scale up the size of the
        training images by.\
        """
        )
    parser.add_argument(
        '--random_brightness',
        type=int,
        default=0,
        help="""\
        A percentage determining how much to randomly multiply the training image
        input pixels up or down by.\
        """
        )
    FLAGS, unparsed = parser.parse_known_args()
    tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)


# print the current datetime
print('finish: ', str(time.ctime()), '\n')
print("this took --- %s seconds ---" % round(time.time() - start, 2))
# Out:
# start:  Wed Apr 25 14:40:40 2018
#
#
# Looking for images in 'A'
#
# Looking for images in 'B'
#
# Looking for images in 'C'
#
# Looking for images in 'D'
#
# Looking for images in 'E'
#
# Looking for images in 'F'
# /tmp/bottleneck\A\label_A _0_1382.png
# /tmp/bottleneck\A\label_A _0_1446.png
# /tmp/bottleneck\A\label_A _0_1540.png
# /tmp/bottleneck\A\label_A _0_1894.png
# /tmp/bottleneck\A\label_A _0_192.png
# /tmp/bottleneck\A\label_A _0_2042.png
# /tmp/bottleneck\A\label_A _0_2150.png
# /tmp/bottleneck\A\label_A _0_2165.png
# /tmp/bottleneck\A\label_A _0_2282.png
# /tmp/bottleneck\A\label_A _0_234.png
# /tmp/bottleneck\A\label_A _0_2352.png
# /tmp/bottleneck\A\label_A _0_2612.png
# /tmp/bottleneck\A\label_A _0_2657.png
# /tmp/bottleneck\A\label_A _0_2721.png
# /tmp/bottleneck\A\label_A _0_2778.png
# /tmp/bottleneck\A\label_A _0_2874.png
# /tmp/bottleneck\A\label_A _0_3050.png
# /tmp/bottleneck\A\label_A _0_3179.png
# /tmp/bottleneck\A\label_A _0_3234.png
# /tmp/bottleneck\A\label_A _0_3431.png
# /tmp/bottleneck\A\label_A _0_3535.png
# /tmp/bottleneck\A\label_A _0_3887.png
# /tmp/bottleneck\A\label_A _0_3910.png
# /tmp/bottleneck\A\label_A _0_3964.png
# /tmp/bottleneck\A\label_A _0_4031.png
# /tmp/bottleneck\A\label_A _0_4133.png
# /tmp/bottleneck\A\label_A _0_4474.png
# /tmp/bottleneck\A\label_A _0_4517.png
# /tmp/bottleneck\A\label_A _0_4612.png
# /tmp/bottleneck\A\label_A _0_466.png
# /tmp/bottleneck\A\label_A _0_4682.png
# /tmp/bottleneck\A\label_A _0_4733.png
# /tmp/bottleneck\A\label_A _0_4775.png
# /tmp/bottleneck\A\label_A _0_5353.png
# /tmp/bottleneck\A\label_A _0_5571.png
# /tmp/bottleneck\A\label_A _0_5578.png
# /tmp/bottleneck\A\label_A _0_5608.png
# /tmp/bottleneck\A\label_A _0_5812.png
# /tmp/bottleneck\A\label_A _0_5823.png
# /tmp/bottleneck\A\label_A _0_5928.png
# /tmp/bottleneck\A\label_A _0_5930.png
# /tmp/bottleneck\A\label_A _0_60.png
# /tmp/bottleneck\A\label_A _0_6429.png
# /tmp/bottleneck\A\label_A _0_6814.png
# /tmp/bottleneck\A\label_A _0_6857.png
# /tmp/bottleneck\A\label_A _0_6874.png
# /tmp/bottleneck\A\label_A _0_6945.png
# /tmp/bottleneck\A\label_A _0_728.png
# /tmp/bottleneck\A\label_A _0_7406.png
# /tmp/bottleneck\A\label_A _0_7486.png
# /tmp/bottleneck\A\label_A _0_7539.png
# /tmp/bottleneck\A\label_A _0_7684.png
# /tmp/bottleneck\A\label_A _0_7705.png
# /tmp/bottleneck\A\label_A _0_7780.png
# /tmp/bottleneck\A\label_A _0_7791.png
# /tmp/bottleneck\A\label_A _0_7849.png
# /tmp/bottleneck\A\label_A _0_7878.png
# /tmp/bottleneck\A\label_A _0_7931.png
# /tmp/bottleneck\A\label_A _0_8046.png
# /tmp/bottleneck\A\label_A _0_8072.png
# /tmp/bottleneck\A\label_A _0_8097.png
# /tmp/bottleneck\A\label_A _0_8199.png
# /tmp/bottleneck\A\label_A _0_8219.png
# /tmp/bottleneck\A\label_A _0_8231.png
# /tmp/bottleneck\A\label_A _0_8406.png
# /tmp/bottleneck\A\label_A _0_8420.png
# /tmp/bottleneck\A\label_A _0_8742.png
# /tmp/bottleneck\A\label_A _0_881.png
# /tmp/bottleneck\A\label_A _0_8824.png
# /tmp/bottleneck\A\label_A _0_9046.png
# /tmp/bottleneck\A\label_A _0_9233.png
# /tmp/bottleneck\A\label_A _0_9465.png
# /tmp/bottleneck\A\label_A _0_9466.png
# /tmp/bottleneck\A\label_A _0_962.png
# /tmp/bottleneck\A\label_A _0_9632.png
# /tmp/bottleneck\A\label_A _0_9951.png
# /tmp/bottleneck\A\label_A _10_1216.png
# /tmp/bottleneck\A\label_A _10_129.png
# /tmp/bottleneck\A\label_A _10_146.png
# /tmp/bottleneck\A\label_A _10_1584.png
# /tmp/bottleneck\A\label_A _10_162.png
# /tmp/bottleneck\A\label_A _10_1703.png
# /tmp/bottleneck\A\label_A _10_1711.png
# /tmp/bottleneck\A\label_A _10_1738.png
# /tmp/bottleneck\A\label_A _10_1840.png
# /tmp/bottleneck\A\label_A _10_1856.png
# /tmp/bottleneck\A\label_A _10_2054.png
# /tmp/bottleneck\A\label_A _10_2087.png
# /tmp/bottleneck\A\label_A _10_2379.png
# /tmp/bottleneck\A\label_A _10_2834.png
# /tmp/bottleneck\A\label_A _10_3111.png
# /tmp/bottleneck\A\label_A _10_3284.png
# /tmp/bottleneck\A\label_A _10_3560.png
# /tmp/bottleneck\A\label_A _10_3701.png
# /tmp/bottleneck\A\label_A _10_3750.png
# /tmp/bottleneck\A\label_A _10_3831.png
# /tmp/bottleneck\A\label_A _10_3844.png
# /tmp/bottleneck\A\label_A _10_3917.png
# /tmp/bottleneck\A\label_A _10_3968.png
# /tmp/bottleneck\A\label_A _10_4168.png
# 100 bottleneck files created.
# /tmp/bottleneck\A\label_A _10_4205.png
# /tmp/bottleneck\A\label_A _10_4273.png
# /tmp/bottleneck\A\label_A _10_4320.png
# /tmp/bottleneck\A\label_A _10_4357.png
# /tmp/bottleneck\A\label_A _10_4543.png
# /tmp/bottleneck\A\label_A _10_4993.png
# /tmp/bottleneck\A\label_A _10_5003.png
# /tmp/bottleneck\A\label_A _10_5321.png
# /tmp/bottleneck\A\label_A _10_5510.png
# /tmp/bottleneck\A\label_A _10_5629.png
# /tmp/bottleneck\A\label_A _10_5840.png
# /tmp/bottleneck\A\label_A _10_5912.png
# /tmp/bottleneck\A\label_A _10_613.png
# /tmp/bottleneck\A\label_A _10_6173.png
# /tmp/bottleneck\A\label_A _10_6178.png
# /tmp/bottleneck\A\label_A _10_6623.png
# /tmp/bottleneck\A\label_A _10_6697.png
# /tmp/bottleneck\A\label_A _10_674.png
# /tmp/bottleneck\A\label_A _10_6804.png
# /tmp/bottleneck\A\label_A _10_6811.png
# /tmp/bottleneck\A\label_A _10_693.png
# /tmp/bottleneck\A\label_A _10_703.png
# /tmp/bottleneck\A\label_A _10_7085.png
# /tmp/bottleneck\A\label_A _10_7098.png
# /tmp/bottleneck\A\label_A _10_7299.png
# /tmp/bottleneck\A\label_A _10_7378.png
# /tmp/bottleneck\A\label_A _10_7441.png
# /tmp/bottleneck\A\label_A _10_7522.png
# /tmp/bottleneck\A\label_A _10_7546.png
# /tmp/bottleneck\A\label_A _10_763.png
# /tmp/bottleneck\A\label_A _10_7819.png
# /tmp/bottleneck\A\label_A _10_7899.png
# /tmp/bottleneck\A\label_A _10_7987.png
# /tmp/bottleneck\A\label_A _10_8206.png
# /tmp/bottleneck\A\label_A _10_8236.png
# /tmp/bottleneck\A\label_A _10_8258.png
# /tmp/bottleneck\A\label_A _10_8275.png
# /tmp/bottleneck\A\label_A _10_8303.png
# /tmp/bottleneck\A\label_A _10_8376.png
# /tmp/bottleneck\A\label_A _10_8394.png
# /tmp/bottleneck\A\label_A _10_8462.png
# /tmp/bottleneck\A\label_A _10_8690.png
# /tmp/bottleneck\A\label_A _10_8743.png
# /tmp/bottleneck\A\label_A _10_8761.png
# /tmp/bottleneck\A\label_A _10_9032.png
# /tmp/bottleneck\A\label_A _10_9149.png
# /tmp/bottleneck\A\label_A _10_9163.png
# /tmp/bottleneck\A\label_A _10_9234.png
# /tmp/bottleneck\A\label_A _10_9258.png
# /tmp/bottleneck\A\label_A _10_9362.png
# /tmp/bottleneck\A\label_A _10_9383.png
# /tmp/bottleneck\A\label_A _10_9580.png
# /tmp/bottleneck\A\label_A _10_965.png
# /tmp/bottleneck\A\label_A _11_1063.png
# /tmp/bottleneck\A\label_A _11_1177.png
# /tmp/bottleneck\A\label_A _11_12.png
# /tmp/bottleneck\A\label_A _11_125.png
# /tmp/bottleneck\A\label_A _11_1366.png
# /tmp/bottleneck\A\label_A _11_1563.png
# /tmp/bottleneck\A\label_A _11_1808.png
# /tmp/bottleneck\A\label_A _11_1819.png
# /tmp/bottleneck\A\label_A _11_190.png
# /tmp/bottleneck\A\label_A _11_2034.png
# /tmp/bottleneck\A\label_A _11_208.png
# /tmp/bottleneck\A\label_A _11_2111.png
# /tmp/bottleneck\A\label_A _11_2183.png
# /tmp/bottleneck\A\label_A _11_2447.png
# /tmp/bottleneck\A\label_A _11_2760.png
# /tmp/bottleneck\A\label_A _11_2884.png
# /tmp/bottleneck\A\label_A _11_2925.png
# /tmp/bottleneck\A\label_A _11_2933.png
# /tmp/bottleneck\A\label_A _11_2965.png
# /tmp/bottleneck\A\label_A _11_2989.png
# /tmp/bottleneck\A\label_A _11_2999.png
# /tmp/bottleneck\A\label_A _11_301.png
# /tmp/bottleneck\A\label_A _11_3022.png
# /tmp/bottleneck\A\label_A _11_3092.png
# /tmp/bottleneck\A\label_A _11_3104.png
# /tmp/bottleneck\A\label_A _11_3258.png
# /tmp/bottleneck\A\label_A _11_3320.png
# /tmp/bottleneck\A\label_A _11_3339.png
# /tmp/bottleneck\A\label_A _11_3665.png
# /tmp/bottleneck\A\label_A _11_376.png
# /tmp/bottleneck\A\label_A _11_3980.png
# /tmp/bottleneck\A\label_A _11_4031.png
# /tmp/bottleneck\A\label_A _11_4174.png
# /tmp/bottleneck\A\label_A _11_4199.png
# /tmp/bottleneck\A\label_A _11_428.png
# /tmp/bottleneck\A\label_A _11_4443.png
# /tmp/bottleneck\A\label_A _11_4984.png
# /tmp/bottleneck\A\label_A _11_4993.png
# /tmp/bottleneck\A\label_A _11_5070.png
# /tmp/bottleneck\A\label_A _11_5157.png
# /tmp/bottleneck\A\label_A _11_5161.png
# /tmp/bottleneck\A\label_A _11_5256.png
# /tmp/bottleneck\A\label_A _11_5292.png
# /tmp/bottleneck\A\label_A _11_5652.png
# /tmp/bottleneck\A\label_A _11_5737.png
# /tmp/bottleneck\A\label_A _11_5750.png
# /tmp/bottleneck\A\label_A _11_5879.png
# 200 bottleneck files created.
# /tmp/bottleneck\A\label_A _11_5978.png
# /tmp/bottleneck\A\label_A _11_6017.png
# /tmp/bottleneck\A\label_A _11_6108.png
# /tmp/bottleneck\A\label_A _11_6154.png
# /tmp/bottleneck\A\label_A _11_6253.png
# /tmp/bottleneck\A\label_A _11_6335.png
# /tmp/bottleneck\A\label_A _11_6367.png
# /tmp/bottleneck\A\label_A _11_671.png
# /tmp/bottleneck\A\label_A _11_6767.png
# /tmp/bottleneck\A\label_A _11_7382.png
# /tmp/bottleneck\A\label_A _11_7554.png
# /tmp/bottleneck\A\label_A _11_7741.png
# /tmp/bottleneck\A\label_A _11_7931.png
# /tmp/bottleneck\A\label_A _11_7978.png
# /tmp/bottleneck\A\label_A _11_8190.png
# /tmp/bottleneck\A\label_A _11_8448.png
# /tmp/bottleneck\A\label_A _11_8730.png
# /tmp/bottleneck\A\label_A _11_8739.png
# /tmp/bottleneck\A\label_A _11_8839.png
# /tmp/bottleneck\A\label_A _11_90.png
# /tmp/bottleneck\A\label_A _11_9009.png
# /tmp/bottleneck\A\label_A _11_901.png
# /tmp/bottleneck\A\label_A _11_9348.png
# /tmp/bottleneck\A\label_A _11_9510.png
# /tmp/bottleneck\A\label_A _11_9626.png
# /tmp/bottleneck\A\label_A _11_9658.png
# /tmp/bottleneck\A\label_A _11_9701.png
# /tmp/bottleneck\A\label_A _11_9717.png
# /tmp/bottleneck\A\label_A _11_9817.png
# /tmp/bottleneck\A\label_A _11_9906.png
# /tmp/bottleneck\A\label_A _11_9920.png
# /tmp/bottleneck\A\label_A _12_1214.png
# /tmp/bottleneck\A\label_A _12_1505.png
# /tmp/bottleneck\A\label_A _12_1511.png
# /tmp/bottleneck\A\label_A _12_1526.png
# /tmp/bottleneck\A\label_A _12_1632.png
# /tmp/bottleneck\A\label_A _12_1673.png
# /tmp/bottleneck\A\label_A _12_1681.png
# /tmp/bottleneck\A\label_A _12_170.png
# /tmp/bottleneck\A\label_A _12_1710.png
# /tmp/bottleneck\A\label_A _12_175.png
# /tmp/bottleneck\A\label_A _12_1829.png
# /tmp/bottleneck\A\label_A _12_1887.png
# /tmp/bottleneck\A\label_A _12_2076.png
# /tmp/bottleneck\A\label_A _12_2229.png
# /tmp/bottleneck\A\label_A _12_2271.png
# /tmp/bottleneck\A\label_A _12_2389.png
# /tmp/bottleneck\A\label_A _12_2515.png
# /tmp/bottleneck\A\label_A _12_2636.png
# /tmp/bottleneck\A\label_A _12_2777.png
# /tmp/bottleneck\A\label_A _12_2806.png
# /tmp/bottleneck\A\label_A _12_2875.png
# /tmp/bottleneck\A\label_A _12_2964.png
# /tmp/bottleneck\A\label_A _12_3151.png
# /tmp/bottleneck\A\label_A _12_3452.png
# /tmp/bottleneck\A\label_A _12_3503.png
# /tmp/bottleneck\A\label_A _12_3826.png
# /tmp/bottleneck\A\label_A _12_3949.png
# /tmp/bottleneck\A\label_A _12_4004.png
# /tmp/bottleneck\A\label_A _12_4075.png
# /tmp/bottleneck\A\label_A _12_4142.png
# /tmp/bottleneck\A\label_A _12_4288.png
# /tmp/bottleneck\A\label_A _12_4402.png
# /tmp/bottleneck\A\label_A _12_4405.png
# /tmp/bottleneck\A\label_A _12_4476.png
# /tmp/bottleneck\A\label_A _12_4508.png
# /tmp/bottleneck\A\label_A _12_4800.png
# /tmp/bottleneck\A\label_A _12_492.png
# /tmp/bottleneck\A\label_A _12_5171.png
# /tmp/bottleneck\A\label_A _12_519.png
# /tmp/bottleneck\A\label_A _12_5327.png
# /tmp/bottleneck\A\label_A _12_5518.png
# /tmp/bottleneck\A\label_A _12_5665.png
# /tmp/bottleneck\A\label_A _12_5976.png
# /tmp/bottleneck\A\label_A _12_5995.png
# /tmp/bottleneck\A\label_A _12_6135.png
# /tmp/bottleneck\A\label_A _12_6229.png
# /tmp/bottleneck\A\label_A _12_6572.png
# /tmp/bottleneck\A\label_A _12_6630.png
# /tmp/bottleneck\A\label_A _12_6761.png
# /tmp/bottleneck\A\label_A _12_682.png
# /tmp/bottleneck\A\label_A _12_7263.png
# /tmp/bottleneck\A\label_A _12_7364.png
# /tmp/bottleneck\A\label_A _12_751.png
# /tmp/bottleneck\A\label_A _12_7543.png
# /tmp/bottleneck\A\label_A _12_7549.png
# /tmp/bottleneck\A\label_A _12_7580.png
# /tmp/bottleneck\A\label_A _12_7695.png
# /tmp/bottleneck\A\label_A _12_772.png
# /tmp/bottleneck\A\label_A _12_7808.png
# /tmp/bottleneck\A\label_A _12_7880.png
# /tmp/bottleneck\A\label_A _12_8219.png
# /tmp/bottleneck\A\label_A _12_8227.png
# /tmp/bottleneck\A\label_A _12_8309.png
# /tmp/bottleneck\A\label_A _12_8371.png
# /tmp/bottleneck\A\label_A _12_8584.png
# /tmp/bottleneck\A\label_A _12_8678.png
# /tmp/bottleneck\A\label_A _12_8743.png
# /tmp/bottleneck\A\label_A _12_88.png
# /tmp/bottleneck\A\label_A _12_8814.png
# 300 bottleneck files created.
# /tmp/bottleneck\A\label_A _12_8816.png
# /tmp/bottleneck\A\label_A _12_8951.png
# /tmp/bottleneck\A\label_A _12_9005.png
# /tmp/bottleneck\A\label_A _12_9088.png
# /tmp/bottleneck\A\label_A _12_9353.png
# /tmp/bottleneck\A\label_A _12_9496.png
# /tmp/bottleneck\A\label_A _12_9538.png
# /tmp/bottleneck\A\label_A _13_1288.png
# /tmp/bottleneck\A\label_A _13_1351.png
# /tmp/bottleneck\A\label_A _13_1392.png
# /tmp/bottleneck\A\label_A _13_1399.png
# /tmp/bottleneck\A\label_A _13_1451.png
# /tmp/bottleneck\A\label_A _13_1570.png
# /tmp/bottleneck\A\label_A _13_1619.png
# /tmp/bottleneck\A\label_A _13_1621.png
# /tmp/bottleneck\A\label_A _13_1773.png
# /tmp/bottleneck\A\label_A _13_1820.png
# /tmp/bottleneck\A\label_A _13_2020.png
# /tmp/bottleneck\A\label_A _13_205.png
# /tmp/bottleneck\A\label_A _13_2150.png
# /tmp/bottleneck\A\label_A _13_2261.png
# /tmp/bottleneck\A\label_A _13_2270.png
# /tmp/bottleneck\A\label_A _13_2519.png
# /tmp/bottleneck\A\label_A _13_259.png
# /tmp/bottleneck\A\label_A _13_2703.png
# /tmp/bottleneck\A\label_A _13_2784.png
# /tmp/bottleneck\A\label_A _13_2953.png
# /tmp/bottleneck\A\label_A _13_340.png
# /tmp/bottleneck\A\label_A _13_3457.png
# /tmp/bottleneck\A\label_A _13_350.png
# /tmp/bottleneck\A\label_A _13_3669.png
# /tmp/bottleneck\A\label_A _13_3848.png
# /tmp/bottleneck\A\label_A _13_386.png
# /tmp/bottleneck\A\label_A _13_4304.png
# /tmp/bottleneck\A\label_A _13_4430.png
# /tmp/bottleneck\A\label_A _13_4575.png
# /tmp/bottleneck\A\label_A _13_4615.png
# /tmp/bottleneck\A\label_A _13_4717.png
# /tmp/bottleneck\A\label_A _13_4853.png
# /tmp/bottleneck\A\label_A _13_4951.png
# /tmp/bottleneck\A\label_A _13_4982.png
# /tmp/bottleneck\A\label_A _13_5018.png
# /tmp/bottleneck\A\label_A _13_5115.png
# /tmp/bottleneck\A\label_A _13_523.png
# /tmp/bottleneck\A\label_A _13_5238.png
# /tmp/bottleneck\A\label_A _13_531.png
# /tmp/bottleneck\A\label_A _13_5575.png
# /tmp/bottleneck\A\label_A _13_5625.png
# /tmp/bottleneck\A\label_A _13_5713.png
# /tmp/bottleneck\A\label_A _13_5856.png
# /tmp/bottleneck\A\label_A _13_5910.png
# /tmp/bottleneck\A\label_A _13_596.png
# /tmp/bottleneck\A\label_A _13_5986.png
# /tmp/bottleneck\A\label_A _13_6056.png
# /tmp/bottleneck\A\label_A _13_6183.png
# /tmp/bottleneck\A\label_A _13_6244.png
# /tmp/bottleneck\A\label_A _13_6367.png
# /tmp/bottleneck\A\label_A _13_6460.png
# /tmp/bottleneck\A\label_A _13_6704.png
# /tmp/bottleneck\A\label_A _13_6773.png
# /tmp/bottleneck\A\label_A _13_6798.png
# /tmp/bottleneck\A\label_A _13_7079.png
# /tmp/bottleneck\A\label_A _13_712.png
# /tmp/bottleneck\A\label_A _13_7259.png
# /tmp/bottleneck\A\label_A _13_7426.png
# /tmp/bottleneck\A\label_A _13_7444.png
# /tmp/bottleneck\A\label_A _13_7480.png
# /tmp/bottleneck\A\label_A _13_7686.png
# /tmp/bottleneck\A\label_A _13_7720.png
# /tmp/bottleneck\A\label_A _13_7773.png
# /tmp/bottleneck\A\label_A _13_7891.png
# /tmp/bottleneck\A\label_A _13_7935.png
# /tmp/bottleneck\A\label_A _13_8137.png
# /tmp/bottleneck\A\label_A _13_8248.png
# /tmp/bottleneck\A\label_A _13_8261.png
# /tmp/bottleneck\A\label_A _13_8308.png
# /tmp/bottleneck\A\label_A _13_8406.png
# /tmp/bottleneck\A\label_A _13_8618.png
# /tmp/bottleneck\A\label_A _13_8681.png
# /tmp/bottleneck\A\label_A _13_8705.png
# /tmp/bottleneck\A\label_A _13_8706.png
# /tmp/bottleneck\A\label_A _13_8816.png
# /tmp/bottleneck\A\label_A _13_9232.png
# /tmp/bottleneck\A\label_A _13_9270.png
# /tmp/bottleneck\A\label_A _13_9748.png
# /tmp/bottleneck\A\label_A _14_1023.png
# /tmp/bottleneck\A\label_A _14_1085.png
# /tmp/bottleneck\A\label_A _14_1153.png
# /tmp/bottleneck\A\label_A _14_1165.png
# /tmp/bottleneck\A\label_A _14_1508.png
# /tmp/bottleneck\A\label_A _14_160.png
# /tmp/bottleneck\A\label_A _14_1858.png
# /tmp/bottleneck\A\label_A _14_1869.png
# /tmp/bottleneck\A\label_A _14_1872.png
# /tmp/bottleneck\A\label_A _14_1894.png
# /tmp/bottleneck\A\label_A _14_2027.png
# /tmp/bottleneck\A\label_A _14_2150.png
# /tmp/bottleneck\A\label_A _14_2219.png
# /tmp/bottleneck\A\label_A _14_2298.png
# /tmp/bottleneck\A\label_A _14_2441.png
# 400 bottleneck files created.
# /tmp/bottleneck\A\label_A _14_2556.png
# /tmp/bottleneck\A\label_A _14_2660.png
# /tmp/bottleneck\A\label_A _14_2663.png
# /tmp/bottleneck\A\label_A _14_2677.png
# /tmp/bottleneck\A\label_A _14_2747.png
# /tmp/bottleneck\A\label_A _14_2840.png
# /tmp/bottleneck\A\label_A _14_2846.png
# /tmp/bottleneck\A\label_A _14_2908.png
# /tmp/bottleneck\A\label_A _14_3156.png
# /tmp/bottleneck\A\label_A _14_3597.png
# /tmp/bottleneck\A\label_A _14_3776.png
# /tmp/bottleneck\A\label_A _14_3949.png
# /tmp/bottleneck\A\label_A _14_4319.png
# /tmp/bottleneck\A\label_A _14_4326.png
# /tmp/bottleneck\A\label_A _14_4437.png
# /tmp/bottleneck\A\label_A _14_457.png
# /tmp/bottleneck\A\label_A _14_4610.png
# /tmp/bottleneck\A\label_A _14_4684.png
# /tmp/bottleneck\A\label_A _14_4827.png
# /tmp/bottleneck\A\label_A _14_4986.png
# /tmp/bottleneck\A\label_A _14_5093.png
# /tmp/bottleneck\A\label_A _14_5116.png
# /tmp/bottleneck\A\label_A _14_5204.png
# /tmp/bottleneck\A\label_A _14_5623.png
# /tmp/bottleneck\A\label_A _14_5711.png
# /tmp/bottleneck\A\label_A _14_5756.png
# /tmp/bottleneck\A\label_A _14_5819.png
# /tmp/bottleneck\A\label_A _14_5860.png
# /tmp/bottleneck\A\label_A _14_5869.png
# /tmp/bottleneck\A\label_A _14_5975.png
# /tmp/bottleneck\A\label_A _14_6107.png
# /tmp/bottleneck\A\label_A _14_6313.png
# /tmp/bottleneck\A\label_A _14_647.png
# /tmp/bottleneck\A\label_A _14_6484.png
# /tmp/bottleneck\A\label_A _14_6680.png
# /tmp/bottleneck\A\label_A _14_6723.png
# /tmp/bottleneck\A\label_A _14_6732.png
# /tmp/bottleneck\A\label_A _14_6806.png
# /tmp/bottleneck\A\label_A _14_6828.png
# /tmp/bottleneck\A\label_A _14_6897.png
# /tmp/bottleneck\A\label_A _14_6914.png
# /tmp/bottleneck\A\label_A _14_7086.png
# /tmp/bottleneck\A\label_A _14_754.png
# /tmp/bottleneck\A\label_A _14_7541.png
# /tmp/bottleneck\A\label_A _14_7610.png
# /tmp/bottleneck\A\label_A _14_7679.png
# /tmp/bottleneck\A\label_A _14_7793.png
# /tmp/bottleneck\A\label_A _14_8023.png
# /tmp/bottleneck\A\label_A _14_8263.png
# /tmp/bottleneck\A\label_A _14_8559.png
# /tmp/bottleneck\A\label_A _14_8655.png
# /tmp/bottleneck\A\label_A _14_8757.png
# /tmp/bottleneck\A\label_A _14_8829.png
# /tmp/bottleneck\A\label_A _14_8955.png
# /tmp/bottleneck\A\label_A _14_8987.png
# /tmp/bottleneck\A\label_A _14_8990.png
# /tmp/bottleneck\A\label_A _14_8996.png
# /tmp/bottleneck\A\label_A _14_9133.png
# /tmp/bottleneck\A\label_A _14_915.png
# /tmp/bottleneck\A\label_A _14_9242.png
# /tmp/bottleneck\A\label_A _14_931.png
# /tmp/bottleneck\A\label_A _14_9365.png
# /tmp/bottleneck\A\label_A _14_9710.png
# /tmp/bottleneck\A\label_A _14_9946.png
# /tmp/bottleneck\A\label_A _15_1026.png
# /tmp/bottleneck\A\label_A _15_1073.png
# /tmp/bottleneck\A\label_A _15_1299.png
# /tmp/bottleneck\A\label_A _15_145.png
# /tmp/bottleneck\A\label_A _15_1462.png
# /tmp/bottleneck\A\label_A _15_1523.png
# /tmp/bottleneck\A\label_A _15_1638.png
# /tmp/bottleneck\A\label_A _15_1709.png
# /tmp/bottleneck\A\label_A _15_1750.png
# /tmp/bottleneck\A\label_A _15_176.png
# /tmp/bottleneck\A\label_A _15_1862.png
# /tmp/bottleneck\A\label_A _15_2045.png
# /tmp/bottleneck\A\label_A _15_2283.png
# /tmp/bottleneck\A\label_A _15_2318.png
# /tmp/bottleneck\A\label_A _15_2347.png
# /tmp/bottleneck\A\label_A _15_2353.png
# /tmp/bottleneck\A\label_A _15_2420.png
# /tmp/bottleneck\A\label_A _15_2473.png
# /tmp/bottleneck\A\label_A _15_2481.png
# /tmp/bottleneck\A\label_A _15_2545.png
# /tmp/bottleneck\A\label_A _15_2627.png
# /tmp/bottleneck\A\label_A _15_2910.png
# /tmp/bottleneck\A\label_A _15_3054.png
# /tmp/bottleneck\A\label_A _15_3187.png
# /tmp/bottleneck\A\label_A _15_3254.png
# /tmp/bottleneck\A\label_A _15_342.png
# /tmp/bottleneck\A\label_A _15_362.png
# /tmp/bottleneck\A\label_A _15_3630.png
# /tmp/bottleneck\A\label_A _15_3861.png
# /tmp/bottleneck\A\label_A _15_4021.png
# /tmp/bottleneck\A\label_A _15_4076.png
# /tmp/bottleneck\A\label_A _15_410.png
# /tmp/bottleneck\A\label_A _15_4150.png
# /tmp/bottleneck\A\label_A _15_4236.png
# /tmp/bottleneck\A\label_A _15_4564.png
# /tmp/bottleneck\A\label_A _15_5075.png
# 500 bottleneck files created.
# /tmp/bottleneck\A\label_A _15_5324.png
# /tmp/bottleneck\A\label_A _15_5370.png
# /tmp/bottleneck\A\label_A _15_5532.png
# /tmp/bottleneck\A\label_A _15_5562.png
# /tmp/bottleneck\A\label_A _15_5584.png
# /tmp/bottleneck\A\label_A _15_5659.png
# /tmp/bottleneck\A\label_A _15_5694.png
# /tmp/bottleneck\A\label_A _15_574.png
# /tmp/bottleneck\A\label_A _15_5797.png
# /tmp/bottleneck\A\label_A _15_5827.png
# /tmp/bottleneck\A\label_A _15_5831.png
# /tmp/bottleneck\A\label_A _15_5882.png
# /tmp/bottleneck\A\label_A _15_6031.png
# /tmp/bottleneck\A\label_A _15_6113.png
# /tmp/bottleneck\A\label_A _15_629.png
# /tmp/bottleneck\A\label_A _15_634.png
# /tmp/bottleneck\A\label_A _15_6488.png
# /tmp/bottleneck\A\label_A _15_6491.png
# /tmp/bottleneck\A\label_A _15_6616.png
# /tmp/bottleneck\A\label_A _15_6642.png
# /tmp/bottleneck\A\label_A _15_6653.png
# /tmp/bottleneck\A\label_A _15_6690.png
# /tmp/bottleneck\A\label_A _15_6734.png
# /tmp/bottleneck\A\label_A _15_6901.png
# /tmp/bottleneck\A\label_A _15_6905.png
# /tmp/bottleneck\A\label_A _15_6913.png
# /tmp/bottleneck\A\label_A _15_7339.png
# /tmp/bottleneck\A\label_A _15_7535.png
# /tmp/bottleneck\A\label_A _15_7682.png
# /tmp/bottleneck\A\label_A _15_7691.png
# /tmp/bottleneck\A\label_A _15_774.png
# /tmp/bottleneck\A\label_A _15_7901.png
# /tmp/bottleneck\A\label_A _15_80.png
# /tmp/bottleneck\A\label_A _15_8186.png
# /tmp/bottleneck\A\label_A _15_8498.png
# /tmp/bottleneck\A\label_A _15_8667.png
# /tmp/bottleneck\A\label_A _15_8752.png
# /tmp/bottleneck\A\label_A _15_9096.png
# /tmp/bottleneck\A\label_A _15_9118.png
# /tmp/bottleneck\A\label_A _15_9191.png
# /tmp/bottleneck\A\label_A _15_9272.png
# /tmp/bottleneck\A\label_A _15_9294.png
# /tmp/bottleneck\A\label_A _15_9738.png
# /tmp/bottleneck\A\label_A _16_1019.png
# /tmp/bottleneck\A\label_A _16_102.png
# /tmp/bottleneck\A\label_A _16_1038.png
# /tmp/bottleneck\A\label_A _16_104.png
# /tmp/bottleneck\A\label_A _16_1073.png
# /tmp/bottleneck\A\label_A _16_1089.png
# /tmp/bottleneck\A\label_A _16_1137.png
# /tmp/bottleneck\A\label_A _16_121.png
# /tmp/bottleneck\A\label_A _16_1225.png
# /tmp/bottleneck\A\label_A _16_1291.png
# /tmp/bottleneck\A\label_A _16_1316.png
# /tmp/bottleneck\A\label_A _16_147.png
# /tmp/bottleneck\A\label_A _16_1922.png
# /tmp/bottleneck\A\label_A _16_1998.png
# /tmp/bottleneck\A\label_A _16_2087.png
# /tmp/bottleneck\A\label_A _16_2118.png
# /tmp/bottleneck\A\label_A _16_2161.png
# /tmp/bottleneck\A\label_A _16_2186.png
# /tmp/bottleneck\A\label_A _16_2261.png
# /tmp/bottleneck\A\label_A _16_2282.png
# /tmp/bottleneck\A\label_A _16_2370.png
# /tmp/bottleneck\A\label_A _16_2463.png
# /tmp/bottleneck\A\label_A _16_271.png
# /tmp/bottleneck\A\label_A _16_2784.png
# /tmp/bottleneck\A\label_A _16_2793.png
# /tmp/bottleneck\A\label_A _16_2824.png
# /tmp/bottleneck\A\label_A _16_2901.png
# /tmp/bottleneck\A\label_A _16_3011.png
# /tmp/bottleneck\A\label_A _16_3159.png
# /tmp/bottleneck\A\label_A _16_3366.png
# /tmp/bottleneck\A\label_A _16_3869.png
# /tmp/bottleneck\A\label_A _16_3955.png
# /tmp/bottleneck\A\label_A _16_4.png
# /tmp/bottleneck\A\label_A _16_4072.png
# /tmp/bottleneck\A\label_A _16_4161.png
# /tmp/bottleneck\A\label_A _16_4362.png
# /tmp/bottleneck\A\label_A _16_4656.png
# /tmp/bottleneck\A\label_A _16_4841.png
# /tmp/bottleneck\A\label_A _16_4974.png
# /tmp/bottleneck\A\label_A _16_5389.png
# /tmp/bottleneck\A\label_A _16_5415.png
# /tmp/bottleneck\A\label_A _16_5458.png
# /tmp/bottleneck\A\label_A _16_5666.png
# /tmp/bottleneck\A\label_A _16_585.png
# /tmp/bottleneck\A\label_A _16_587.png
# /tmp/bottleneck\A\label_A _16_6.png
# /tmp/bottleneck\A\label_A _16_6206.png
# /tmp/bottleneck\A\label_A _16_6344.png
# /tmp/bottleneck\A\label_A _16_6672.png
# /tmp/bottleneck\A\label_A _16_6677.png
# /tmp/bottleneck\A\label_A _16_6694.png
# /tmp/bottleneck\A\label_A _16_695.png
# /tmp/bottleneck\A\label_A _16_7123.png
# /tmp/bottleneck\A\label_A _16_733.png
# /tmp/bottleneck\A\label_A _16_7426.png
# /tmp/bottleneck\A\label_A _16_7496.png
# /tmp/bottleneck\A\label_A _16_781.png
# 600 bottleneck files created.
# /tmp/bottleneck\A\label_A _16_790.png
# /tmp/bottleneck\A\label_A _16_806.png
# /tmp/bottleneck\A\label_A _16_8067.png
# /tmp/bottleneck\A\label_A _16_8165.png
# /tmp/bottleneck\A\label_A _16_8330.png
# /tmp/bottleneck\A\label_A _16_8765.png
# /tmp/bottleneck\A\label_A _16_8971.png
# /tmp/bottleneck\A\label_A _16_8990.png
# /tmp/bottleneck\A\label_A _16_9089.png
# /tmp/bottleneck\A\label_A _16_9195.png
# /tmp/bottleneck\A\label_A _16_9308.png
# /tmp/bottleneck\A\label_A _16_936.png
# /tmp/bottleneck\A\label_A _16_9362.png
# /tmp/bottleneck\A\label_A _16_940.png
# /tmp/bottleneck\A\label_A _16_949.png
# /tmp/bottleneck\A\label_A _16_9521.png
# /tmp/bottleneck\A\label_A _16_9581.png
# /tmp/bottleneck\A\label_A _16_9627.png
# /tmp/bottleneck\A\label_A _16_9631.png
# /tmp/bottleneck\A\label_A _16_9762.png
# /tmp/bottleneck\A\label_A _16_9908.png
# /tmp/bottleneck\A\label_A _16_9920.png
# /tmp/bottleneck\A\label_A _16_9929.png
# /tmp/bottleneck\A\label_A _16_9958.png
# /tmp/bottleneck\A\label_A _17_102.png
# /tmp/bottleneck\A\label_A _17_1051.png
# /tmp/bottleneck\A\label_A _17_1135.png
# /tmp/bottleneck\A\label_A _17_1144.png
# /tmp/bottleneck\A\label_A _17_1201.png
# /tmp/bottleneck\A\label_A _17_1365.png
# /tmp/bottleneck\A\label_A _17_1376.png
# /tmp/bottleneck\A\label_A _17_1589.png
# /tmp/bottleneck\A\label_A _17_183.png
# /tmp/bottleneck\A\label_A _17_1936.png
# /tmp/bottleneck\A\label_A _17_2055.png
# /tmp/bottleneck\A\label_A _17_2160.png
# /tmp/bottleneck\A\label_A _17_2218.png
# /tmp/bottleneck\A\label_A _17_2235.png
# /tmp/bottleneck\A\label_A _17_2437.png
# /tmp/bottleneck\A\label_A _17_2460.png
# /tmp/bottleneck\A\label_A _17_2465.png
# /tmp/bottleneck\A\label_A _17_2619.png
# /tmp/bottleneck\A\label_A _17_2627.png
# /tmp/bottleneck\A\label_A _17_2944.png
# /tmp/bottleneck\A\label_A _17_3141.png
# /tmp/bottleneck\A\label_A _17_3168.png
# /tmp/bottleneck\A\label_A _17_320.png
# /tmp/bottleneck\A\label_A _17_3288.png
# /tmp/bottleneck\A\label_A _17_3321.png
# /tmp/bottleneck\A\label_A _17_3432.png
# /tmp/bottleneck\A\label_A _17_3473.png
# /tmp/bottleneck\A\label_A _17_3776.png
# /tmp/bottleneck\A\label_A _17_3847.png
# /tmp/bottleneck\A\label_A _17_3854.png
# /tmp/bottleneck\A\label_A _17_3950.png
# /tmp/bottleneck\A\label_A _17_4035.png
# /tmp/bottleneck\A\label_A _17_41.png
# /tmp/bottleneck\A\label_A _17_4261.png
# /tmp/bottleneck\A\label_A _17_4407.png
# /tmp/bottleneck\A\label_A _17_4412.png
# /tmp/bottleneck\A\label_A _17_4528.png
# /tmp/bottleneck\A\label_A _17_4539.png
# /tmp/bottleneck\A\label_A _17_4627.png
# /tmp/bottleneck\A\label_A _17_4737.png
# /tmp/bottleneck\A\label_A _17_5037.png
# /tmp/bottleneck\A\label_A _17_5141.png
# /tmp/bottleneck\A\label_A _17_5340.png
# /tmp/bottleneck\A\label_A _17_5353.png
# /tmp/bottleneck\A\label_A _17_5432.png
# /tmp/bottleneck\A\label_A _17_5584.png
# /tmp/bottleneck\A\label_A _17_5736.png
# /tmp/bottleneck\A\label_A _17_5771.png
# /tmp/bottleneck\A\label_A _17_5921.png
# /tmp/bottleneck\A\label_A _17_6245.png
# /tmp/bottleneck\A\label_A _17_6306.png
# /tmp/bottleneck\A\label_A _17_6460.png
# /tmp/bottleneck\A\label_A _17_6548.png
# /tmp/bottleneck\A\label_A _17_6566.png
# /tmp/bottleneck\A\label_A _17_6612.png
# /tmp/bottleneck\A\label_A _17_6646.png
# /tmp/bottleneck\A\label_A _17_668.png
# /tmp/bottleneck\A\label_A _17_6716.png
# /tmp/bottleneck\A\label_A _17_6729.png
# /tmp/bottleneck\A\label_A _17_6883.png
# /tmp/bottleneck\A\label_A _17_6891.png
# /tmp/bottleneck\A\label_A _17_7001.png
# /tmp/bottleneck\A\label_A _17_7211.png
# /tmp/bottleneck\A\label_A _17_74.png
# /tmp/bottleneck\A\label_A _17_7446.png
# /tmp/bottleneck\A\label_A _17_7658.png
# /tmp/bottleneck\A\label_A _17_7915.png
# /tmp/bottleneck\A\label_A _17_8141.png
# /tmp/bottleneck\A\label_A _17_8147.png
# /tmp/bottleneck\A\label_A _17_8238.png
# /tmp/bottleneck\A\label_A _17_8297.png
# /tmp/bottleneck\A\label_A _17_8388.png
# /tmp/bottleneck\A\label_A _17_8414.png
# /tmp/bottleneck\A\label_A _17_8509.png
# /tmp/bottleneck\A\label_A _17_8530.png
# /tmp/bottleneck\A\label_A _17_8578.png
# 700 bottleneck files created.
# /tmp/bottleneck\A\label_A _17_9017.png
# /tmp/bottleneck\A\label_A _17_9109.png
# /tmp/bottleneck\A\label_A _17_9287.png
# /tmp/bottleneck\A\label_A _17_9360.png
# /tmp/bottleneck\A\label_A _17_9645.png
# /tmp/bottleneck\A\label_A _17_9957.png
# /tmp/bottleneck\A\label_A _17_9981.png
# /tmp/bottleneck\A\label_A _18_1014.png
# /tmp/bottleneck\A\label_A _18_1270.png
# /tmp/bottleneck\A\label_A _18_1292.png
# /tmp/bottleneck\A\label_A _18_1325.png
# /tmp/bottleneck\A\label_A _18_1531.png
# /tmp/bottleneck\A\label_A _18_1561.png
# /tmp/bottleneck\A\label_A _18_1764.png
# /tmp/bottleneck\A\label_A _18_1906.png
# /tmp/bottleneck\A\label_A _18_1977.png
# /tmp/bottleneck\A\label_A _18_2283.png
# /tmp/bottleneck\A\label_A _18_2294.png
# /tmp/bottleneck\A\label_A _18_2338.png
# /tmp/bottleneck\A\label_A _18_2363.png
# /tmp/bottleneck\A\label_A _18_2522.png
# /tmp/bottleneck\A\label_A _18_2723.png
# /tmp/bottleneck\A\label_A _18_2751.png
# /tmp/bottleneck\A\label_A _18_3100.png
# /tmp/bottleneck\A\label_A _18_3132.png
# /tmp/bottleneck\A\label_A _18_3436.png
# /tmp/bottleneck\A\label_A _18_3559.png
# /tmp/bottleneck\A\label_A _18_3622.png
# /tmp/bottleneck\A\label_A _18_379.png
# /tmp/bottleneck\A\label_A _18_3817.png
# /tmp/bottleneck\A\label_A _18_4281.png
# /tmp/bottleneck\A\label_A _18_4341.png
# /tmp/bottleneck\A\label_A _18_438.png
# /tmp/bottleneck\A\label_A _18_447.png
# /tmp/bottleneck\A\label_A _18_4743.png
# /tmp/bottleneck\A\label_A _18_4895.png
# /tmp/bottleneck\A\label_A _18_5000.png
# /tmp/bottleneck\A\label_A _18_5019.png
# /tmp/bottleneck\A\label_A _18_506.png
# /tmp/bottleneck\A\label_A _18_5236.png
# /tmp/bottleneck\A\label_A _18_5243.png
# /tmp/bottleneck\A\label_A _18_5488.png
# /tmp/bottleneck\A\label_A _18_5627.png
# /tmp/bottleneck\A\label_A _18_5651.png
# /tmp/bottleneck\A\label_A _18_589.png
# /tmp/bottleneck\A\label_A _18_6019.png
# /tmp/bottleneck\A\label_A _18_6178.png
# /tmp/bottleneck\A\label_A _18_6202.png
# /tmp/bottleneck\A\label_A _18_6279.png
# /tmp/bottleneck\A\label_A _18_6581.png
# /tmp/bottleneck\A\label_A _18_6670.png
# /tmp/bottleneck\A\label_A _18_6736.png
# /tmp/bottleneck\A\label_A _18_6898.png
# /tmp/bottleneck\A\label_A _18_7014.png
# /tmp/bottleneck\A\label_A _18_7047.png
# /tmp/bottleneck\A\label_A _18_707.png
# /tmp/bottleneck\A\label_A _18_7292.png
# /tmp/bottleneck\A\label_A _18_7546.png
# /tmp/bottleneck\A\label_A _18_7649.png
# /tmp/bottleneck\A\label_A _18_7991.png
# /tmp/bottleneck\A\label_A _18_8075.png
# /tmp/bottleneck\A\label_A _18_8246.png
# /tmp/bottleneck\A\label_A _18_8259.png
# /tmp/bottleneck\A\label_A _18_8267.png
# /tmp/bottleneck\A\label_A _18_8345.png
# /tmp/bottleneck\A\label_A _18_8551.png
# /tmp/bottleneck\A\label_A _18_8587.png
# /tmp/bottleneck\A\label_A _18_8645.png
# /tmp/bottleneck\A\label_A _18_8657.png
# /tmp/bottleneck\A\label_A _18_8670.png
# /tmp/bottleneck\A\label_A _18_8672.png
# /tmp/bottleneck\A\label_A _18_89.png
# /tmp/bottleneck\A\label_A _18_8951.png
# /tmp/bottleneck\A\label_A _18_897.png
# /tmp/bottleneck\A\label_A _18_911.png
# /tmp/bottleneck\A\label_A _18_9176.png
# /tmp/bottleneck\A\label_A _18_9281.png
# /tmp/bottleneck\A\label_A _18_935.png
# /tmp/bottleneck\A\label_A _18_9504.png
# /tmp/bottleneck\A\label_A _18_9524.png
# /tmp/bottleneck\A\label_A _18_9667.png
# /tmp/bottleneck\A\label_A _18_9902.png
# /tmp/bottleneck\A\label_A _18_9914.png
# /tmp/bottleneck\A\label_A _19_1104.png
# /tmp/bottleneck\A\label_A _19_1470.png
# /tmp/bottleneck\A\label_A _19_1646.png
# /tmp/bottleneck\A\label_A _19_1784.png
# /tmp/bottleneck\A\label_A _19_2013.png
# /tmp/bottleneck\A\label_A _19_2016.png
# /tmp/bottleneck\A\label_A _19_2125.png
# /tmp/bottleneck\A\label_A _19_2340.png
# /tmp/bottleneck\A\label_A _19_2361.png
# /tmp/bottleneck\A\label_A _19_2404.png
# /tmp/bottleneck\A\label_A _19_244.png
# /tmp/bottleneck\A\label_A _19_2609.png
# /tmp/bottleneck\A\label_A _19_2650.png
# /tmp/bottleneck\A\label_A _19_2665.png
# /tmp/bottleneck\A\label_A _19_2820.png
# /tmp/bottleneck\A\label_A _19_2874.png
# /tmp/bottleneck\A\label_A _19_3307.png
# 800 bottleneck files created.
# /tmp/bottleneck\A\label_A _19_3351.png
# /tmp/bottleneck\A\label_A _19_3453.png
# /tmp/bottleneck\A\label_A _19_3489.png
# /tmp/bottleneck\A\label_A _19_3612.png
# /tmp/bottleneck\A\label_A _19_3692.png
# /tmp/bottleneck\A\label_A _19_3777.png
# /tmp/bottleneck\A\label_A _19_3999.png
# /tmp/bottleneck\A\label_A _19_4085.png
# /tmp/bottleneck\A\label_A _19_4340.png
# /tmp/bottleneck\A\label_A _19_4426.png
# /tmp/bottleneck\A\label_A _19_4432.png
# /tmp/bottleneck\A\label_A _19_4630.png
# /tmp/bottleneck\A\label_A _19_4639.png
# /tmp/bottleneck\A\label_A _19_4899.png
# /tmp/bottleneck\A\label_A _19_491.png
# /tmp/bottleneck\A\label_A _19_5068.png
# /tmp/bottleneck\A\label_A _19_5162.png
# /tmp/bottleneck\A\label_A _19_5208.png
# /tmp/bottleneck\A\label_A _19_5263.png
# /tmp/bottleneck\A\label_A _19_527.png
# /tmp/bottleneck\A\label_A _19_5277.png
# /tmp/bottleneck\A\label_A _19_5292.png
# /tmp/bottleneck\A\label_A _19_5320.png
# /tmp/bottleneck\A\label_A _19_5341.png
# /tmp/bottleneck\A\label_A _19_5409.png
# /tmp/bottleneck\A\label_A _19_5509.png
# /tmp/bottleneck\A\label_A _19_5529.png
# /tmp/bottleneck\A\label_A _19_5573.png
# /tmp/bottleneck\A\label_A _19_5781.png
# /tmp/bottleneck\A\label_A _19_5927.png
# /tmp/bottleneck\A\label_A _19_6044.png
# /tmp/bottleneck\A\label_A _19_6048.png
# /tmp/bottleneck\A\label_A _19_6168.png
# /tmp/bottleneck\A\label_A _19_622.png
# /tmp/bottleneck\A\label_A _19_6352.png
# /tmp/bottleneck\A\label_A _19_6406.png
# /tmp/bottleneck\A\label_A _19_659.png
# /tmp/bottleneck\A\label_A _19_6628.png
# /tmp/bottleneck\A\label_A _19_6765.png
# /tmp/bottleneck\A\label_A _19_6904.png
# /tmp/bottleneck\A\label_A _19_70.png
# /tmp/bottleneck\A\label_A _19_700.png
# /tmp/bottleneck\A\label_A _19_7014.png
# /tmp/bottleneck\A\label_A _19_7343.png
# /tmp/bottleneck\A\label_A _19_7439.png
# /tmp/bottleneck\A\label_A _19_7553.png
# /tmp/bottleneck\A\label_A _19_7566.png
# /tmp/bottleneck\A\label_A _19_7741.png
# /tmp/bottleneck\A\label_A _19_783.png
# /tmp/bottleneck\A\label_A _19_7901.png
# /tmp/bottleneck\A\label_A _19_8070.png
# /tmp/bottleneck\A\label_A _19_8136.png
# /tmp/bottleneck\A\label_A _19_8196.png
# /tmp/bottleneck\A\label_A _19_8201.png
# /tmp/bottleneck\A\label_A _19_8248.png
# /tmp/bottleneck\A\label_A _19_8618.png
# /tmp/bottleneck\A\label_A _19_8787.png
# /tmp/bottleneck\A\label_A _19_9216.png
# /tmp/bottleneck\A\label_A _19_9293.png
# /tmp/bottleneck\A\label_A _19_9310.png
# /tmp/bottleneck\A\label_A _19_938.png
# /tmp/bottleneck\A\label_A _19_9396.png
# /tmp/bottleneck\A\label_A _19_9413.png
# /tmp/bottleneck\A\label_A _19_9534.png
# /tmp/bottleneck\A\label_A _1_1030.png
# /tmp/bottleneck\A\label_A _1_1127.png
# /tmp/bottleneck\A\label_A _1_1175.png
# /tmp/bottleneck\A\label_A _1_1230.png
# /tmp/bottleneck\A\label_A _1_1274.png
# /tmp/bottleneck\A\label_A _1_1372.png
# /tmp/bottleneck\A\label_A _1_1439.png
# /tmp/bottleneck\A\label_A _1_1486.png
# /tmp/bottleneck\A\label_A _1_1753.png
# /tmp/bottleneck\A\label_A _1_2053.png
# /tmp/bottleneck\A\label_A _1_2145.png
# /tmp/bottleneck\A\label_A _1_2470.png
# /tmp/bottleneck\A\label_A _1_2568.png
# /tmp/bottleneck\A\label_A _1_2883.png
# /tmp/bottleneck\A\label_A _1_3214.png
# /tmp/bottleneck\A\label_A _1_3310.png
# /tmp/bottleneck\A\label_A _1_332.png
# /tmp/bottleneck\A\label_A _1_3462.png
# /tmp/bottleneck\A\label_A _1_3721.png
# /tmp/bottleneck\A\label_A _1_376.png
# /tmp/bottleneck\A\label_A _1_3807.png
# /tmp/bottleneck\A\label_A _1_4002.png
# /tmp/bottleneck\A\label_A _1_402.png
# /tmp/bottleneck\A\label_A _1_4067.png
# /tmp/bottleneck\A\label_A _1_4279.png
# /tmp/bottleneck\A\label_A _1_4298.png
# /tmp/bottleneck\A\label_A _1_4334.png
# /tmp/bottleneck\A\label_A _1_4502.png
# /tmp/bottleneck\A\label_A _1_4615.png
# /tmp/bottleneck\A\label_A _1_4629.png
# /tmp/bottleneck\A\label_A _1_4650.png
# /tmp/bottleneck\A\label_A _1_4763.png
# /tmp/bottleneck\A\label_A _1_4871.png
# /tmp/bottleneck\A\label_A _1_4884.png
# /tmp/bottleneck\A\label_A _1_4899.png
# /tmp/bottleneck\A\label_A _1_5183.png
# 900 bottleneck files created.
# /tmp/bottleneck\A\label_A _1_5443.png
# /tmp/bottleneck\A\label_A _1_5552.png
# /tmp/bottleneck\A\label_A _1_5748.png
# /tmp/bottleneck\A\label_A _1_5808.png
# /tmp/bottleneck\A\label_A _1_5848.png
# /tmp/bottleneck\A\label_A _1_6036.png
# /tmp/bottleneck\A\label_A _1_6079.png
# /tmp/bottleneck\A\label_A _1_61.png
# /tmp/bottleneck\A\label_A _1_623.png
# /tmp/bottleneck\A\label_A _1_6233.png
# /tmp/bottleneck\A\label_A _1_6239.png
# /tmp/bottleneck\A\label_A _1_6459.png
# /tmp/bottleneck\A\label_A _1_6488.png
# /tmp/bottleneck\A\label_A _1_6527.png
# /tmp/bottleneck\A\label_A _1_6760.png
# /tmp/bottleneck\A\label_A _1_6772.png
# /tmp/bottleneck\A\label_A _1_6820.png
# /tmp/bottleneck\A\label_A _1_7041.png
# /tmp/bottleneck\A\label_A _1_7132.png
# /tmp/bottleneck\A\label_A _1_7174.png
# /tmp/bottleneck\A\label_A _1_7429.png
# /tmp/bottleneck\A\label_A _1_7445.png
# /tmp/bottleneck\A\label_A _1_7460.png
# /tmp/bottleneck\A\label_A _1_7538.png
# /tmp/bottleneck\A\label_A _1_7550.png
# /tmp/bottleneck\A\label_A _1_7874.png
# /tmp/bottleneck\A\label_A _1_7950.png
# /tmp/bottleneck\A\label_A _1_8160.png
# /tmp/bottleneck\A\label_A _1_8179.png
# /tmp/bottleneck\A\label_A _1_819.png
# /tmp/bottleneck\A\label_A _1_8232.png
# /tmp/bottleneck\A\label_A _1_8491.png
# /tmp/bottleneck\A\label_A _1_8609.png
# /tmp/bottleneck\A\label_A _1_8639.png
# /tmp/bottleneck\A\label_A _1_87.png
# /tmp/bottleneck\A\label_A _1_8755.png
# /tmp/bottleneck\A\label_A _1_8783.png
# /tmp/bottleneck\A\label_A _1_8836.png
# /tmp/bottleneck\A\label_A _1_9013.png
# /tmp/bottleneck\A\label_A _1_9289.png
# /tmp/bottleneck\A\label_A _1_9423.png
# /tmp/bottleneck\A\label_A _1_9471.png
# /tmp/bottleneck\A\label_A _1_9661.png
# /tmp/bottleneck\A\label_A _1_9716.png
# /tmp/bottleneck\A\label_A _1_9908.png
# /tmp/bottleneck\A\label_A _1_9963.png
# /tmp/bottleneck\A\label_A _20_1080.png
# /tmp/bottleneck\A\label_A _20_1097.png
# /tmp/bottleneck\A\label_A _20_1359.png
# /tmp/bottleneck\A\label_A _20_1493.png
# /tmp/bottleneck\A\label_A _20_1506.png
# /tmp/bottleneck\A\label_A _20_1717.png
# /tmp/bottleneck\A\label_A _20_1950.png
# /tmp/bottleneck\A\label_A _20_2119.png
# /tmp/bottleneck\A\label_A _20_2223.png
# /tmp/bottleneck\A\label_A _20_2558.png
# /tmp/bottleneck\A\label_A _20_2651.png
# /tmp/bottleneck\A\label_A _20_2687.png
# /tmp/bottleneck\A\label_A _20_2850.png
# /tmp/bottleneck\A\label_A _20_2890.png
# /tmp/bottleneck\A\label_A _20_2929.png
# /tmp/bottleneck\A\label_A _20_3152.png
# /tmp/bottleneck\A\label_A _20_3246.png
# /tmp/bottleneck\A\label_A _20_327.png
# /tmp/bottleneck\A\label_A _20_3391.png
# /tmp/bottleneck\A\label_A _20_342.png
# /tmp/bottleneck\A\label_A _20_3427.png
# /tmp/bottleneck\A\label_A _20_3527.png
# /tmp/bottleneck\A\label_A _20_3685.png
# /tmp/bottleneck\A\label_A _20_3802.png
# /tmp/bottleneck\A\label_A _20_4026.png
# /tmp/bottleneck\A\label_A _20_4177.png
# /tmp/bottleneck\A\label_A _20_4205.png
# /tmp/bottleneck\A\label_A _20_4275.png
# /tmp/bottleneck\A\label_A _20_4307.png
# /tmp/bottleneck\A\label_A _20_4368.png
# /tmp/bottleneck\A\label_A _20_459.png
# /tmp/bottleneck\A\label_A _20_4696.png
# /tmp/bottleneck\A\label_A _20_4718.png
# /tmp/bottleneck\A\label_A _20_4772.png
# /tmp/bottleneck\A\label_A _20_4840.png
# /tmp/bottleneck\A\label_A _20_5026.png
# /tmp/bottleneck\A\label_A _20_5099.png
# /tmp/bottleneck\A\label_A _20_5132.png
# /tmp/bottleneck\A\label_A _20_5214.png
# /tmp/bottleneck\A\label_A _20_5315.png
# /tmp/bottleneck\A\label_A _20_541.png
# /tmp/bottleneck\A\label_A _20_5433.png
# /tmp/bottleneck\A\label_A _20_5435.png
# /tmp/bottleneck\A\label_A _20_546.png
# /tmp/bottleneck\A\label_A _20_5717.png
# /tmp/bottleneck\A\label_A _20_5734.png
# /tmp/bottleneck\A\label_A _20_5767.png
# /tmp/bottleneck\A\label_A _20_5803.png
# /tmp/bottleneck\A\label_A _20_6062.png
# /tmp/bottleneck\A\label_A _20_6084.png
# /tmp/bottleneck\A\label_A _20_6150.png
# /tmp/bottleneck\A\label_A _20_6435.png
# /tmp/bottleneck\A\label_A _20_6482.png
# /tmp/bottleneck\A\label_A _20_6569.png
# 1000 bottleneck files created.
# /tmp/bottleneck\A\label_A _20_6595.png
# /tmp/bottleneck\A\label_A _20_6723.png
# /tmp/bottleneck\A\label_A _20_6844.png
# /tmp/bottleneck\A\label_A _20_688.png
# /tmp/bottleneck\A\label_A _20_6899.png
# /tmp/bottleneck\A\label_A _20_6941.png
# /tmp/bottleneck\A\label_A _20_7849.png
# /tmp/bottleneck\A\label_A _20_8062.png
# /tmp/bottleneck\A\label_A _20_8197.png
# /tmp/bottleneck\A\label_A _20_8459.png
# /tmp/bottleneck\A\label_A _20_8484.png
# /tmp/bottleneck\A\label_A _20_9112.png
# /tmp/bottleneck\A\label_A _20_9134.png
# /tmp/bottleneck\A\label_A _20_9183.png
# /tmp/bottleneck\A\label_A _20_9233.png
# /tmp/bottleneck\A\label_A _20_9342.png
# /tmp/bottleneck\A\label_A _20_9368.png
# /tmp/bottleneck\A\label_A _20_9383.png
# /tmp/bottleneck\A\label_A _20_9456.png
# /tmp/bottleneck\A\label_A _20_9678.png
# /tmp/bottleneck\A\label_A _20_9693.png
# /tmp/bottleneck\A\label_A _20_9853.png
# /tmp/bottleneck\A\label_A _20_9940.png
# /tmp/bottleneck\A\label_A _21_1241.png
# /tmp/bottleneck\A\label_A _21_1287.png
# /tmp/bottleneck\A\label_A _21_1365.png
# /tmp/bottleneck\A\label_A _21_1452.png
# /tmp/bottleneck\A\label_A _21_1510.png
# /tmp/bottleneck\A\label_A _21_1535.png
# /tmp/bottleneck\A\label_A _21_1636.png
# /tmp/bottleneck\A\label_A _21_1659.png
# /tmp/bottleneck\A\label_A _21_2076.png
# /tmp/bottleneck\A\label_A _21_2177.png
# /tmp/bottleneck\A\label_A _21_2355.png
# /tmp/bottleneck\A\label_A _21_2584.png
# /tmp/bottleneck\A\label_A _21_2941.png
# /tmp/bottleneck\A\label_A _21_313.png
# /tmp/bottleneck\A\label_A _21_317.png
# /tmp/bottleneck\A\label_A _21_3220.png
# /tmp/bottleneck\A\label_A _21_323.png
# /tmp/bottleneck\A\label_A _21_3249.png
# /tmp/bottleneck\A\label_A _21_330.png
# /tmp/bottleneck\A\label_A _21_3351.png
# /tmp/bottleneck\A\label_A _21_3391.png
# /tmp/bottleneck\A\label_A _21_3470.png
# /tmp/bottleneck\A\label_A _21_3566.png
# /tmp/bottleneck\A\label_A _21_3813.png
# /tmp/bottleneck\A\label_A _21_4118.png
# /tmp/bottleneck\A\label_A _21_4281.png
# /tmp/bottleneck\A\label_A _21_4317.png
# /tmp/bottleneck\A\label_A _21_4501.png
# /tmp/bottleneck\A\label_A _21_4528.png
# /tmp/bottleneck\A\label_A _21_472.png
# /tmp/bottleneck\A\label_A _21_4773.png
# /tmp/bottleneck\A\label_A _21_4923.png
# /tmp/bottleneck\A\label_A _21_5157.png
# /tmp/bottleneck\A\label_A _21_5262.png
# /tmp/bottleneck\A\label_A _21_5641.png
# /tmp/bottleneck\A\label_A _21_6030.png
# /tmp/bottleneck\A\label_A _21_6308.png
# /tmp/bottleneck\A\label_A _21_6466.png
# /tmp/bottleneck\A\label_A _21_6631.png
# /tmp/bottleneck\A\label_A _21_6695.png
# /tmp/bottleneck\A\label_A _21_6810.png
# /tmp/bottleneck\A\label_A _21_6829.png
# /tmp/bottleneck\A\label_A _21_690.png
# /tmp/bottleneck\A\label_A _21_6922.png
# /tmp/bottleneck\A\label_A _21_7146.png
# /tmp/bottleneck\A\label_A _21_7228.png
# /tmp/bottleneck\A\label_A _21_7283.png
# /tmp/bottleneck\A\label_A _21_7432.png
# /tmp/bottleneck\A\label_A _21_7435.png
# /tmp/bottleneck\A\label_A _21_748.png
# /tmp/bottleneck\A\label_A _21_7521.png
# /tmp/bottleneck\A\label_A _21_771.png
# /tmp/bottleneck\A\label_A _21_7896.png
# /tmp/bottleneck\A\label_A _21_7901.png
# /tmp/bottleneck\A\label_A _21_7907.png
# /tmp/bottleneck\A\label_A _21_7912.png
# /tmp/bottleneck\A\label_A _21_796.png
# /tmp/bottleneck\A\label_A _21_7966.png
# /tmp/bottleneck\A\label_A _21_8.png
# /tmp/bottleneck\A\label_A _21_8276.png
# /tmp/bottleneck\A\label_A _21_8281.png
# /tmp/bottleneck\A\label_A _21_8331.png
# /tmp/bottleneck\A\label_A _21_8333.png
# /tmp/bottleneck\A\label_A _21_8366.png
# /tmp/bottleneck\A\label_A _21_8424.png
# /tmp/bottleneck\A\label_A _21_843.png
# /tmp/bottleneck\A\label_A _21_8696.png
# /tmp/bottleneck\A\label_A _21_8824.png
# /tmp/bottleneck\A\label_A _21_8920.png
# /tmp/bottleneck\A\label_A _21_9192.png
# /tmp/bottleneck\A\label_A _21_9281.png
# /tmp/bottleneck\A\label_A _21_9394.png
# /tmp/bottleneck\A\label_A _21_9590.png
# /tmp/bottleneck\A\label_A _21_9602.png
# /tmp/bottleneck\A\label_A _21_9630.png
# /tmp/bottleneck\A\label_A _21_9704.png
# /tmp/bottleneck\A\label_A _21_9731.png
# 1100 bottleneck files created.
# /tmp/bottleneck\A\label_A _21_9759.png
# /tmp/bottleneck\A\label_A _21_9808.png
# /tmp/bottleneck\A\label_A _21_9934.png
# /tmp/bottleneck\A\label_A _22_1034.png
# /tmp/bottleneck\A\label_A _22_1363.png
# /tmp/bottleneck\A\label_A _22_1669.png
# /tmp/bottleneck\A\label_A _22_1751.png
# /tmp/bottleneck\A\label_A _22_189.png
# /tmp/bottleneck\A\label_A _22_1914.png
# /tmp/bottleneck\A\label_A _22_204.png
# /tmp/bottleneck\A\label_A _22_2123.png
# /tmp/bottleneck\A\label_A _22_2207.png
# /tmp/bottleneck\A\label_A _22_2361.png
# /tmp/bottleneck\A\label_A _22_2487.png
# /tmp/bottleneck\A\label_A _22_2579.png
# /tmp/bottleneck\A\label_A _22_2764.png
# /tmp/bottleneck\A\label_A _22_2836.png
# /tmp/bottleneck\A\label_A _22_2878.png
# /tmp/bottleneck\A\label_A _22_3113.png
# /tmp/bottleneck\A\label_A _22_3461.png
# /tmp/bottleneck\A\label_A _22_3794.png
# /tmp/bottleneck\A\label_A _22_3864.png
# /tmp/bottleneck\A\label_A _22_4196.png
# /tmp/bottleneck\A\label_A _22_4296.png
# /tmp/bottleneck\A\label_A _22_4315.png
# /tmp/bottleneck\A\label_A _22_478.png
# /tmp/bottleneck\A\label_A _22_4867.png
# /tmp/bottleneck\A\label_A _22_4868.png
# /tmp/bottleneck\A\label_A _22_49.png
# /tmp/bottleneck\A\label_A _22_4930.png
# /tmp/bottleneck\A\label_A _22_4934.png
# /tmp/bottleneck\A\label_A _22_499.png
# /tmp/bottleneck\A\label_A _22_5101.png
# /tmp/bottleneck\A\label_A _22_5124.png
# /tmp/bottleneck\A\label_A _22_5282.png
# /tmp/bottleneck\A\label_A _22_5304.png
# /tmp/bottleneck\A\label_A _22_5662.png
# /tmp/bottleneck\A\label_A _22_57.png
# /tmp/bottleneck\A\label_A _22_5865.png
# /tmp/bottleneck\A\label_A _22_6279.png
# /tmp/bottleneck\A\label_A _22_6344.png
# /tmp/bottleneck\A\label_A _22_6366.png
# /tmp/bottleneck\A\label_A _22_6395.png
# /tmp/bottleneck\A\label_A _22_6426.png
# /tmp/bottleneck\A\label_A _22_656.png
# /tmp/bottleneck\A\label_A _22_6682.png
# /tmp/bottleneck\A\label_A _22_6705.png
# /tmp/bottleneck\A\label_A _22_6899.png
# /tmp/bottleneck\A\label_A _22_7094.png
# /tmp/bottleneck\A\label_A _22_7104.png
# /tmp/bottleneck\A\label_A _22_7227.png
# /tmp/bottleneck\A\label_A _22_7267.png
# /tmp/bottleneck\A\label_A _22_7278.png
# /tmp/bottleneck\A\label_A _22_7316.png
# /tmp/bottleneck\A\label_A _22_7330.png
# /tmp/bottleneck\A\label_A _22_7394.png
# /tmp/bottleneck\A\label_A _22_7687.png
# /tmp/bottleneck\A\label_A _22_7716.png
# /tmp/bottleneck\A\label_A _22_7787.png
# /tmp/bottleneck\A\label_A _22_7789.png
# /tmp/bottleneck\A\label_A _22_7855.png
# /tmp/bottleneck\A\label_A _22_8180.png
# /tmp/bottleneck\A\label_A _22_8210.png
# /tmp/bottleneck\A\label_A _22_8213.png
# /tmp/bottleneck\A\label_A _22_831.png
# /tmp/bottleneck\A\label_A _22_850.png
# /tmp/bottleneck\A\label_A _22_8567.png
# /tmp/bottleneck\A\label_A _22_8609.png
# /tmp/bottleneck\A\label_A _22_864.png
# /tmp/bottleneck\A\label_A _22_8896.png
# /tmp/bottleneck\A\label_A _22_8914.png
# /tmp/bottleneck\A\label_A _22_8928.png
# /tmp/bottleneck\A\label_A _22_8993.png
# /tmp/bottleneck\A\label_A _22_9283.png
# /tmp/bottleneck\A\label_A _22_9603.png
# /tmp/bottleneck\A\label_A _22_9693.png
# /tmp/bottleneck\A\label_A _23_1.png
# /tmp/bottleneck\A\label_A _23_1037.png
# /tmp/bottleneck\A\label_A _23_1102.png
# /tmp/bottleneck\A\label_A _23_1250.png
# /tmp/bottleneck\A\label_A _23_126.png
# /tmp/bottleneck\A\label_A _23_1284.png
# /tmp/bottleneck\A\label_A _23_1335.png
# /tmp/bottleneck\A\label_A _23_1417.png
# /tmp/bottleneck\A\label_A _23_1527.png
# /tmp/bottleneck\A\label_A _23_1596.png
# /tmp/bottleneck\A\label_A _23_1780.png
# /tmp/bottleneck\A\label_A _23_1843.png
# /tmp/bottleneck\A\label_A _23_1919.png
# /tmp/bottleneck\A\label_A _23_2065.png
# /tmp/bottleneck\A\label_A _23_210.png
# /tmp/bottleneck\A\label_A _23_2160.png
# /tmp/bottleneck\A\label_A _23_2179.png
# /tmp/bottleneck\A\label_A _23_2189.png
# /tmp/bottleneck\A\label_A _23_2243.png
# /tmp/bottleneck\A\label_A _23_2290.png
# /tmp/bottleneck\A\label_A _23_2352.png
# /tmp/bottleneck\A\label_A _23_2472.png
# /tmp/bottleneck\A\label_A _23_2522.png
# /tmp/bottleneck\A\label_A _23_2788.png
# 1200 bottleneck files created.
# /tmp/bottleneck\A\label_A _23_3047.png
# /tmp/bottleneck\A\label_A _23_3082.png
# /tmp/bottleneck\A\label_A _23_3280.png
# /tmp/bottleneck\A\label_A _23_3652.png
# /tmp/bottleneck\A\label_A _23_4113.png
# /tmp/bottleneck\A\label_A _23_4167.png
# /tmp/bottleneck\A\label_A _23_4194.png
# /tmp/bottleneck\A\label_A _23_4298.png
# /tmp/bottleneck\A\label_A _23_4342.png
# /tmp/bottleneck\A\label_A _23_4402.png
# /tmp/bottleneck\A\label_A _23_4472.png
# /tmp/bottleneck\A\label_A _23_4486.png
# /tmp/bottleneck\A\label_A _23_4921.png
# /tmp/bottleneck\A\label_A _23_4952.png
# /tmp/bottleneck\A\label_A _23_51.png
# /tmp/bottleneck\A\label_A _23_5117.png
# /tmp/bottleneck\A\label_A _23_5250.png
# /tmp/bottleneck\A\label_A _23_5285.png
# /tmp/bottleneck\A\label_A _23_5323.png
# /tmp/bottleneck\A\label_A _23_5483.png
# /tmp/bottleneck\A\label_A _23_5563.png
# /tmp/bottleneck\A\label_A _23_5565.png
# /tmp/bottleneck\A\label_A _23_6151.png
# /tmp/bottleneck\A\label_A _23_6245.png
# ...
# /tmp/bottleneck\F\label_F _25_4395.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_4741.png
# /tmp/bottleneck\F\label_F _25_4741.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_6490.png
# /tmp/bottleneck\F\label_F _25_6490.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_7250.png
# /tmp/bottleneck\F\label_F _25_7250.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_7492.png
# /tmp/bottleneck\F\label_F _25_7492.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_7793.png
# /tmp/bottleneck\F\label_F _25_7793.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_9618.png
# /tmp/bottleneck\F\label_F _25_9618.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _25_9802.png
# /tmp/bottleneck\F\label_F _25_9802.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_139.png
# /tmp/bottleneck\F\label_F _26_139.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_3450.png
# /tmp/bottleneck\F\label_F _26_3450.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_4985.png
# /tmp/bottleneck\F\label_F _26_4985.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_6875.png
# /tmp/bottleneck\F\label_F _26_6875.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_7046.png
# /tmp/bottleneck\F\label_F _26_7046.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_8229.png
# /tmp/bottleneck\F\label_F _26_8229.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_8944.png
# /tmp/bottleneck\F\label_F _26_8944.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_9207.png
# /tmp/bottleneck\F\label_F _26_9207.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _26_9705.png
# /tmp/bottleneck\F\label_F _26_9705.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_1595.png
# /tmp/bottleneck\F\label_F _27_1595.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_2690.png
# /tmp/bottleneck\F\label_F _27_2690.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_337.png
# /tmp/bottleneck\F\label_F _27_337.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_3446.png
# /tmp/bottleneck\F\label_F _27_3446.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_4520.png
# /tmp/bottleneck\F\label_F _27_4520.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_5031.png
# /tmp/bottleneck\F\label_F _27_5031.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_6436.png
# /tmp/bottleneck\F\label_F _27_6436.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_7546.png
# /tmp/bottleneck\F\label_F _27_7546.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_8192.png
# /tmp/bottleneck\F\label_F _27_8192.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_8809.png
# /tmp/bottleneck\F\label_F _27_8809.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_8851.png
# /tmp/bottleneck\F\label_F _27_8851.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _27_9598.png
# /tmp/bottleneck\F\label_F _27_9598.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_2600.png
# /tmp/bottleneck\F\label_F _28_2600.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_2674.png
# /tmp/bottleneck\F\label_F _28_2674.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_4095.png
# /tmp/bottleneck\F\label_F _28_4095.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_472.png
# /tmp/bottleneck\F\label_F _28_472.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_4973.png
# /tmp/bottleneck\F\label_F _28_4973.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_5988.png
# /tmp/bottleneck\F\label_F _28_5988.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_5997.png
# /tmp/bottleneck\F\label_F _28_5997.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_6215.png
# /tmp/bottleneck\F\label_F _28_6215.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_7061.png
# /tmp/bottleneck\F\label_F _28_7061.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_768.png
# /tmp/bottleneck\F\label_F _28_768.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_8457.png
# /tmp/bottleneck\F\label_F _28_8457.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_8500.png
# /tmp/bottleneck\F\label_F _28_8500.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _28_8703.png
# /tmp/bottleneck\F\label_F _28_8703.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_10.png
# /tmp/bottleneck\F\label_F _29_10.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_2159.png
# /tmp/bottleneck\F\label_F _29_2159.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_218.png
# /tmp/bottleneck\F\label_F _29_218.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_3112.png
# /tmp/bottleneck\F\label_F _29_3112.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_455.png
# /tmp/bottleneck\F\label_F _29_455.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _29_9816.png
# /tmp/bottleneck\F\label_F _29_9816.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_2481.png
# /tmp/bottleneck\F\label_F _2_2481.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_2754.png
# /tmp/bottleneck\F\label_F _2_2754.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_5826.png
# /tmp/bottleneck\F\label_F _2_5826.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_6713.png
# /tmp/bottleneck\F\label_F _2_6713.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_7200.png
# /tmp/bottleneck\F\label_F _2_7200.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_7283.png
# /tmp/bottleneck\F\label_F _2_7283.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _2_8055.png
# /tmp/bottleneck\F\label_F _2_8055.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_4266.png
# /tmp/bottleneck\F\label_F _3_4266.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_4782.png
# /tmp/bottleneck\F\label_F _3_4782.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_4789.png
# /tmp/bottleneck\F\label_F _3_4789.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_5079.png
# /tmp/bottleneck\F\label_F _3_5079.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_6132.png
# /tmp/bottleneck\F\label_F _3_6132.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_6243.png
# /tmp/bottleneck\F\label_F _3_6243.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_6287.png
# /tmp/bottleneck\F\label_F _3_6287.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_7675.png
# /tmp/bottleneck\F\label_F _3_7675.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_7754.png
# /tmp/bottleneck\F\label_F _3_7754.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_8212.png
# /tmp/bottleneck\F\label_F _3_8212.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _3_9235.png
# /tmp/bottleneck\F\label_F _3_9235.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_134.png
# /tmp/bottleneck\F\label_F _4_134.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_1706.png
# /tmp/bottleneck\F\label_F _4_1706.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_3142.png
# /tmp/bottleneck\F\label_F _4_3142.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_4363.png
# /tmp/bottleneck\F\label_F _4_4363.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_4488.png
# /tmp/bottleneck\F\label_F _4_4488.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_5102.png
# /tmp/bottleneck\F\label_F _4_5102.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_5701.png
# /tmp/bottleneck\F\label_F _4_5701.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_622.png
# /tmp/bottleneck\F\label_F _4_622.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_6754.png
# /tmp/bottleneck\F\label_F _4_6754.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_7468.png
# /tmp/bottleneck\F\label_F _4_7468.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_7672.png
# /tmp/bottleneck\F\label_F _4_7672.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_7741.png
# /tmp/bottleneck\F\label_F _4_7741.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _4_8647.png
# /tmp/bottleneck\F\label_F _4_8647.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_142.png
# /tmp/bottleneck\F\label_F _5_142.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_382.png
# /tmp/bottleneck\F\label_F _5_382.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_389.png
# /tmp/bottleneck\F\label_F _5_389.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_4084.png
# /tmp/bottleneck\F\label_F _5_4084.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_5520.png
# /tmp/bottleneck\F\label_F _5_5520.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_6655.png
# /tmp/bottleneck\F\label_F _5_6655.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _5_9296.png
# /tmp/bottleneck\F\label_F _5_9296.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_6004.png
# /tmp/bottleneck\F\label_F _6_6004.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_6266.png
# /tmp/bottleneck\F\label_F _6_6266.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_723.png
# /tmp/bottleneck\F\label_F _6_723.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_7795.png
# /tmp/bottleneck\F\label_F _6_7795.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_8271.png
# /tmp/bottleneck\F\label_F _6_8271.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_8334.png
# /tmp/bottleneck\F\label_F _6_8334.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _6_8588.png
# /tmp/bottleneck\F\label_F _6_8588.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_1947.png
# /tmp/bottleneck\F\label_F _7_1947.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_2163.png
# /tmp/bottleneck\F\label_F _7_2163.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_3525.png
# /tmp/bottleneck\F\label_F _7_3525.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_4772.png
# /tmp/bottleneck\F\label_F _7_4772.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_6256.png
# /tmp/bottleneck\F\label_F _7_6256.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_8268.png
# /tmp/bottleneck\F\label_F _7_8268.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_9579.png
# /tmp/bottleneck\F\label_F _7_9579.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _7_9636.png
# /tmp/bottleneck\F\label_F _7_9636.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_2254.png
# /tmp/bottleneck\F\label_F _8_2254.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_3326.png
# /tmp/bottleneck\F\label_F _8_3326.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_3758.png
# /tmp/bottleneck\F\label_F _8_3758.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_551.png
# /tmp/bottleneck\F\label_F _8_551.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_5940.png
# /tmp/bottleneck\F\label_F _8_5940.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_7320.png
# /tmp/bottleneck\F\label_F _8_7320.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_7539.png
# /tmp/bottleneck\F\label_F _8_7539.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _8_9502.png
# /tmp/bottleneck\F\label_F _8_9502.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_2197.png
# /tmp/bottleneck\F\label_F _9_2197.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_231.png
# /tmp/bottleneck\F\label_F _9_231.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_237.png
# /tmp/bottleneck\F\label_F _9_237.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_3983.png
# /tmp/bottleneck\F\label_F _9_3983.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_5134.png
# /tmp/bottleneck\F\label_F _9_5134.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_6539.png
# /tmp/bottleneck\F\label_F _9_6539.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_6784.png
# /tmp/bottleneck\F\label_F _9_6784.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_8448.png
# /tmp/bottleneck\F\label_F _9_8448.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_8739.png
# /tmp/bottleneck\F\label_F _9_8739.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_9637.png
# /tmp/bottleneck\F\label_F _9_9637.png
# C:/GitHub/HandSign_Recognition/00 Data/own_data_test_pretrained_model\F\label_F _9_9959.png
# /tmp/bottleneck\F\label_F _9_9959.png
# Final test accuracy = 95.6% (N=1533)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# the error message that occurs in window above seems to be due to the simple fact that iPython cannot handle the exit statement
# probably this error can simply be ignored
# for a bit more info on the error, look at the traceback with the magic command %tb:
# %tb

# %%
sys.argv

# %%
# Disable tensorflow compilation warnings
#os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
#import tensorflow as tf

image_path = 'C:/GitHub/HandSign_Recognition/00 Data/TEST/label_A (24).jpg' #sys.argv[1]
print(image_path)

# Read the image_data
image_data = tf.gfile.FastGFile(image_path, 'rb').read()


# Loads label file, strips off carriage return
label_lines = [line.rstrip() for line
                   in tf.gfile.GFile("logs/output_labels.txt")]

# Unpersists graph from file
with tf.gfile.FastGFile("logs/output_graph.pb", 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    _ = tf.import_graph_def(graph_def, name='')

with tf.Session() as sess:
    # Feed the image_data as input to the graph and get first prediction
    softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')

    predictions = sess.run(softmax_tensor, \
             {'DecodeJpeg/contents:0': image_data})

    # Sort to show labels of first prediction in order of confidence
    top_k = predictions[0].argsort()[-len(predictions[0]):][::-1]

    for node_id in top_k:
        human_string = label_lines[node_id]
        score = predictions[0][node_id]
        print('%s (score = %.5f)' % (human_string, score))
# Out:
# C:/GitHub/HandSign_Recognition/00 Data/TEST/label_A (24).jpg
# d (score = 0.19432)
# c (score = 0.17905)
# e (score = 0.16831)
# f (score = 0.16783)
# a (score = 0.16301)
# b (score = 0.12748)
