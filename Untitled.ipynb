# %%
import IPython
IPython.display.Audio("SampleAudio.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-8f86d9ce7e25> in <module>()
#       1 frequency = 2500  # Set Frequency To 2500 Hertz
#       2 duration = 1000  # Set Duration To 1000 ms == 1 second
# ----> 3 winsound.Beep(frequency, duration)
#
# RuntimeError: Failed to beep
